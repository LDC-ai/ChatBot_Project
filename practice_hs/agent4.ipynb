# %%
import os
import torch
import cudf
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.chat_models import ChatOpenAI
from langchain.tools import Tool
from langchain.agents import initialize_agent, AgentType
from langchain.memory import ConversationBufferMemory
from langchain.schema import Document
from dotenv import load_dotenv

# .env 파일 로드
load_dotenv()

# OpenAI API 키를 환경 변수에서 로드
openai_api_key = os.getenv("OPENAI_API_KEY")

# Parquet 파일 경로 설정
file_path = 'merged_data.parquet'

# Parquet 파일을 cudf로 로드
df = cudf.read_parquet(file_path)

# 결측치(NaN)를 'N/A'로 대체
df = df.fillna('N/A')

# 'content' 열을 벡터화하여 생성
df['content'] = (
    'filename: ' + df['filename'].astype(str) + '\n' +
    'date: ' + df['date'].astype(str) + '\n' +
    'conference_number: ' + df['conference_number'].astype(str) + '\n' +
    'question_number: ' + df['question_number'].astype(str) + '\n' +
    'meeting_name: ' + df['meeting_name'].astype(str) + '\n' +
    'generation_number: ' + df['generation_number'].astype(str) + '\n' +
    'committee_name: ' + df['committee_name'].astype(str) + '\n' +
    'meeting_number: ' + df['meeting_number'].astype(str) + '\n' +
    'session_number: ' + df['session_number'].astype(str) + '\n' +
    'agenda: ' + df['agenda'].astype(str) + '\n' +
    'law: ' + df['law'].astype(str) + '\n' +
    'qna_type: ' + df['qna_type'].astype(str) + '\n' +
    'context: ' + df['context'].astype(str) + '\n' +
    'questioner_name: ' + df['questioner_name'].astype(str) + '\n' +
    'questioner_affiliation: ' + df['questioner_affiliation'].astype(str) + '\n' +
    'questioner_position: ' + df['questioner_position'].astype(str) + '\n' +
    'question_comment: ' + df['question_comment'].astype(str) + '\n' +
    'answerer_name: ' + df['answerer_name'].astype(str) + '\n' +
    'answerer_affiliation: ' + df['answerer_affiliation'].astype(str) + '\n' +
    'answerer_position: ' + df['answerer_position'].astype(str) + '\n' +
    'answer_comment: ' + df['answer_comment'].astype(str) + '\n'
)

# cudf DataFrame을 pandas DataFrame으로 변환
# 이 과정은 GPU의 이점을 유지하면서 데이터 변환을 효율적으로 처리할 수 있도록 합니다.
pandas_df = df.to_pandas()

# 'content'와 메타데이터를 분리하여 리스트로 변환
content_list = pandas_df['content'].tolist()
metadata_list = pandas_df.drop(columns=['content']).to_dict('records')

# Document 객체 생성
documents = [Document(page_content=content, metadata=metadata) for content, metadata in zip(content_list, metadata_list)]

# 문서 분할 및 임베딩 생성
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
split_docs = text_splitter.split_documents(documents)

# CUDA 사용 설정
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# 임베딩 모델 설정 (GPU 사용)
embedding_model_name = 'sentence-transformers/all-MiniLM-L6-v2'
embedding_model = HuggingFaceEmbeddings(
    model_name=embedding_model_name,
    model_kwargs={'device': device}
)

# FAISS 인덱스 설정
index_path = 'faiss_index'

# FAISS 인덱스 생성 또는 로드
if os.path.exists(index_path):
    print("저장된 FAISS 인덱스를 로드합니다...")
    vectorstore = FAISS.load_local(
        index_path,
        embeddings=embedding_model,
        allow_dangerous_deserialization=True
    )
else:
    print("FAISS 인덱스를 생성합니다...")
    vectorstore = FAISS.from_documents(split_docs, embedding_model)
    print(f"총 {len(split_docs)}개의 문서가 인덱스에 추가되었습니다.")
    vectorstore.save_local(index_path)


# Retriever 생성
retriever = vectorstore.as_retriever(search_kwargs={"k": 6})

# 도구 함수 정의
def parquet_search_tool(input_text):
    docs = retriever.get_relevant_documents(input_text)
    if docs:
        summaries = [doc.page_content for doc in docs]
        return '\n\n'.join(summaries)
    else:
        return "해당하는 정보를 찾을 수 없습니다."

# 도구 정의
parquet_search_tool = Tool(
    name="ParquetSearch",
    func=parquet_search_tool,
    description=(
        "Parquet 문서에서 특정 인물이나 이슈에 대한 정보를 검색하는 도구입니다. "
        "회의 번호, 회의명, 대수, 위원회명, 안건, 법률, 질의응답 유형, 내용, 요약된 내용, "
        "질문자, 질문 등의 필드를 요약하여 제공합니다."
    )
)

# 도구 목록 생성
tools = [parquet_search_tool]

# LLM 정의
llm = ChatOpenAI(model_name="gpt-4", temperature=0, openai_api_key=openai_api_key)

# 메모리 설정
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

# 에이전트 초기화
agent = initialize_agent(
    tools,
    llm,
    agent=AgentType.CHAT_CONVERSATIONAL_REACT_DESCRIPTION,
    verbose=True,
    memory=memory,
)

# 시스템 프롬프트 설정
agent.agent.llm_chain.prompt.messages[0].prompt.template = (
    "반드시 한국어로 답변해 주세요. "
    "당신은 국회 Parquet 문서에서 인물이나 이슈에 대한 정보를 찾아주는 AI 비서입니다. "
    "사용자가 특정 인물이나 이슈에 대해 질문하면, ParquetSearch 도구를 사용하여 해당 인물이 언급된 회의 정보를 찾아야 합니다. "
    "회의 번호, 회의명, 대수, 위원회명, 안건, 법률, 질의응답 유형, 내용, 요약된 내용, 질문자, 질문 등의 필드를 포함하여 요약된 응답을 제공하세요. "
    "Parquet 문서에서 정보를 찾을 수 없는 경우, 정중하게 해당 정보를 찾을 수 없음을 알려주세요. "
    "도구의 사용 여부를 언급하지 말고 필요한 정보만 제공하세요."
)

# 에이전트와 대화하는 함수 정의
def chat_with_agent(user_input):
    response = agent.run(input=user_input)
    return response

# 예시 질문
user_input = "김영삼 대통령이 언급된 회의에 대한 정보를 알려주세요. 반드시 안건 이름과 날짜, 어떤 회의였는지, 몇 대 국회였는지 알려주세요. 질문자와 답변자에 대한 정보와 어떤 안건에 대해 이야기가 오고 갔는지 대화문도 알려주세요."
response = chat_with_agent(user_input)
print("Assistant:", response)
# Out:
# /tmp/ipykernel_210069/3080195416.py:74: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(
# /home/elicer/.local/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# FAISS 인덱스를 생성합니다...
# 총 26975개의 문서가 인덱스에 추가되었습니다.
# /tmp/ipykernel_210069/3080195416.py:124: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(model_name="gpt-4", temperature=0, openai_api_key=openai_api_key)
# /tmp/ipykernel_210069/3080195416.py:127: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
# /tmp/ipykernel_210069/3080195416.py:130: LangChainDeprecationWarning: The function `initialize_agent` was deprecated in LangChain 0.1.0 and will be removed in 1.0. Use :meth:`~Use new agent constructor methods like create_react_agent, create_json_agent, create_structured_chat_agent, etc.` instead.
#   agent = initialize_agent(
# /tmp/ipykernel_210069/3080195416.py:150: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = agent.run(input=user_input)
# > Entering new AgentExecutor chain...
# ```json
# {
#     "action": "ParquetSearch",
#     "action_input": "김영삼"
# }
# ```
# Observation: answerer_name: 이희범
# answerer_affiliation:
# answerer_position: 2018평창동계올림픽대회및동계패럴림픽대회조직위원장
# answer_comment: 예, 알고 있습니다.   국민안전처를 중심으로 해서 저희 조직위원회하고 통합안전망체제를 지금 하고 있고요. 몇 차례 회의도 지금 하고 있습니다.
#
# answerer_name: 김현숙
# answerer_affiliation: 새만금개발청
# answerer_position: 청장
# answer_comment: 아니요, 지금 말씀을……
#
# answerer_name: 홍남기
# answerer_affiliation: 부총리겸기획재정부
# answerer_position: 장관
# answer_comment: 위원님 지금 말씀 주신 대로 탄소중립은 저희가 선택할 수 있는 사안이 아니고 필수로 가야 되고요. 이것을……
#
# answerer_name: 홍남기
# answerer_affiliation: 기획재정부
# answerer_position: 부총리겸기획재정부장관
# answer_comment: 예.
#
# questioner_name: 김삼화
# questioner_affiliation:
# questioner_position: 소위원장
# question_comment: 수고하셨습니다.   다음, 강병구 교수님 준비하신 내용이 있으면 말씀해 주십시오.
# answerer_name:  강병구
# answerer_affiliation:
# answerer_position: 진술인
#
# questioner_name: 유상범
# questioner_affiliation:
# questioner_position: 의원
# question_comment: 답변하기 곤란하신가요?
# answerer_name: 김부겸
# answerer_affiliation:
# answerer_position: 국무총리
# answer_comment: 예, 제가……
# Thought:
# /tmp/ipykernel_210069/3080195416.py:102: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = retriever.get_relevant_documents(input_text)
# ```json
# {
#     "action": "Final Answer",
#     "action_input": "김영삼 대통령에 대한 회의 정보를 찾았습니다. 이희범이라는 인물이 2018평창동계올림픽대회및동계패럴림픽대회조직위원장으로서 국민안전처와 조직위원회가 통합안전망체제를 구축하고 있다고 언급하였습니다. 또한 김현숙 새만금개발청 청장, 홍남기 부총리겸기획재정부 장관, 홍남기 기획재정부 부총리겸기획재정부장관 등이 참여하였습니다. 김삼화 소위원장이 강병구 교수에게 발언을 요청하였고, 유상범 의원이 김부겸 국무총리에게 질문을 하였습니다. 하지만 회의의 날짜, 안건 이름, 회의명, 몇 대 국회였는지에 대한 정보는 찾을 수 없었습니다."
# }
# ```
#
# > Finished chain.
# Assistant: 김영삼 대통령에 대한 회의 정보를 찾았습니다. 이희범이라는 인물이 2018평창동계올림픽대회및동계패럴림픽대회조직위원장으로서 국민안전처와 조직위원회가 통합안전망체제를 구축하고 있다고 언급하였습니다. 또한 김현숙 새만금개발청 청장, 홍남기 부총리겸기획재정부 장관, 홍남기 기획재정부 부총리겸기획재정부장관 등이 참여하였습니다. 김삼화 소위원장이 강병구 교수에게 발언을 요청하였고, 유상범 의원이 김부겸 국무총리에게 질문을 하였습니다. 하지만 회의의 날짜, 안건 이름, 회의명, 몇 대 국회였는지에 대한 정보는 찾을 수 없었습니다.

# %%
# Retriever 생성
retriever = vectorstore.as_retriever(search_kwargs={"k": 6})

# Retriever가 반환하는 문서 확인
test_query = "김영삼 대통령"
docs = retriever.get_relevant_documents(test_query)

if docs:
    print(f"검색된 문서 수: {len(docs)}")
    for doc in docs:
        print("Content:\n", doc.page_content)
        print("Metadata:\n", doc.metadata)
        print("-" * 50)
else:
    print("검색된 문서가 없습니다.")
# Out:
# 검색된 문서 수: 6
# Content:
#  당시에 외국으로 출국해서 지금 외국에 체류 중인 것으로 알고 있습니다. 그러니까 국민들 입장에서는 도저히 그 상황을 받아들이기가 어렵지요.   허 전 회장 전 사위가 대표를 맡고 있던 건설사로부터 70억 원 채권을 넘겨받은 사건 지금 경찰에서 수사하고 있습니까? 용인에서 있었던 사건인데 서울중앙지검으로 가 있는 것으로 알고 있습니다. 지금은 서울중앙지검에 갔어요? 광주지검하고는 그러면 지금…… 강제집행면탈로 고소되어서 서울중앙지검에 있는 것으로 알고 있습니다.
# Metadata:
#  {'filename': 'SRC_20대_2018_2018년10월23일_국정감사_법제사법위원회_0006(048956).xlsx', 'date': '2018년10월23일(화)', 'conference_number': '048956', 'question_number': '0006', 'meeting_name': '국정감사', 'generation_number': '20', 'committee_name': '법제사법위원회', 'meeting_number': '2018', 'session_number': '2018년10월23일', 'agenda': '감사개시', 'law': '', 'qna_type': '추출형', 'context': '수원을 지역 백혜련 위원입니다.  요즘 사법농단 사태로 인해서 검찰청의 영장기각률이 굉장히 올라갔다고 하는데 특히 서울중앙지검을 기준으로 해서는 예전보다 두 배 이상 영장기각률이 상승했다고 합니다.   그런데 혹시 지금 지역의 각 검찰청들은 영장기각률이 예년에 비해서 특별하게 다른 점이 있다든지 그 점에 대해서 각 검사장님들이 지역 상황을 얘기해 주셨으면 좋겠어요. 청주지검장님부터 대전지검장님, 차례대로 지검장님들이. 저희 광주지검은 영장기각률이 동급 청보다 3% 정도 낮은 상황입니다. 수원을 지역 백혜련 위원입니다.  요즘 사법농단 사태로 인해서 검찰청의 영장기각률이 굉장히 올라갔다고 하는데 특히 서울중앙지검을 기준으로 해서는 예전보다 두 배 이상 영장기각률이 상승했다고 합니다.   그런데 혹시 지금 지역의 각 검찰청들은 영장기각률이 예년에 비해서 특별하게 다른 점이 있다든지 그 점에 대해서 각 검사장님들이 지역 상황을 얘기해 주셨으면 좋겠어요. 청주지검장님부터 대전지검장님, 차례대로 지검장님들이. 저희들은 기각률이 좀 높아진 건 사실입니다. 수원을 지역 백혜련 위원입니다.  요즘 사법농단 사태로 인해서 검찰청의 영장기각률이 굉장히 올라갔다고 하는데 특히 서울중앙지검을 기준으로 해서는 예전보다 두 배 이상 영장기각률이 상승했다고 합니다.   그런데 혹시 지금 지역의 각 검찰청들은 영장기각률이 예년에 비해서 특별하게 다른 점이 있다든지 그 점에 대해서 각 검사장님들이 지역 상황을 얘기해 주셨으면 좋겠어요. 청주지검장님부터 대전지검장님, 차례대로 지검장님들이. 제주지검은 작년보다 조금 낮아졌습니다. 한 2% 정도 낮아졌습니다. 수원을 지역 백혜련 위원입니다.  요즘 사법농단 사태로 인해서 검찰청의 영장기각률이 굉장히 올라갔다고 하는데 특히 서울중앙지검을 기준으로 해서는 예전보다 두 배 이상 영장기각률이 상승했다고 합니다.   그런데 혹시 지금 지역의 각 검찰청들은 영장기각률이 예년에 비해서 특별하게 다른 점이 있다든지 그 점에 대해서 각 검사장님들이 지역 상황을 얘기해 주셨으면 좋겠어요. 청주지검장님부터 대전지검장님, 차례대로 지검장님들이. 전주지검입니다.  여러 해를 비교할 순 없는데 작년하고 비교해서 봤을 때 한 1% 정도 기각률이 높아졌습니다. 큰 의미는 없는 걸로 보입니다. 대전은 어떤가요? 저희 대전은 작년에 비해서 조금 높아지긴 했으나 다른 청에 비해서 큰 변화는 없는 편입니다. 그러니까 예년과는 비슷한 수준이에요? 예, 그렇습니다. 모르세요, 허재호 전 대주그룹 회장 황제노역 사건? 그 허재호 전 대주그룹 회장이 2010년도에 재판을 받으면서 광주고등법원에서 조세포탈 혐의에 대해서 벌금도 엄청 깎이고 몸으로 때울 수 있는 환형유치 기간 역시 대폭 낮추면서 일당 5억 원으로 판결하면서 정말 황제노역이라는 신조어가 탄생하고 유전무죄의 극치를 보여 줬던 사건입니다.  그리고 이 사건에 대해서 온 국민들이 봐 주기 판결이라고 볼 수밖에 없었던 것이 허재호 회장의 선친이 목포지원장 출신의 판사, 여동생은 법무부 교정협의회중앙회장, 매제는 검사였지요. 그리고 사위는 광주지법의 판사 그리고 남동생은 전현직 판사들의 골프모임을 책임지는 법구회 총무, 이런 인적 네트워크로 되어 있는 상태에서 그런 판결이 내려졌기 때문에 더욱이나 이것이 정상적인 판결이라고 보기는 어려웠습니다.  그래서 이런 국민들의 분노가 솟구치니까 서울지방국세청에서 다시 조사해서 국세 63억 원을 탈세한 사실을 적발하고 그중에서 6억 8000만 원을 특정해서 허 전 회장을 고발했습니다.   그런데 결국은 광주지검에서 이 사건에 대해서 또 무혐의 결정을 내렸어요. 무혐의 결정에 대해서 서울지방국세청이 또 불복해서 광구고검에 항고하고 광주고검은 재기수사명령을 내립니다. 결국 재기수사명령을 내렸는데 또 조사하니까 허 전 회장에 대해서는 무혐의 처분을 하고 허 전 회장 관련 회사 관계자 한 명만 벌금 1억 원으로 약식기소를 합니다.   저는 이 수사 과정이 도저히 납득되지 않습니다. 결국은 밝히지 못한 것 아닌가, 부실수사 내지 의지가 없었던 것 아닌가 싶은데요. 관계자 1명에 대해서 1억 원이라는 벌금으로 청구하면서 결국은 정말 책임자라고 할 수 있는 허 전 회장에 대해서는 또 무혐의 처분을 하게 된 것인데요.  이 사건이 완전히 종결된 겁니까, 검사장님? 허 전 회장과 관련된 사건이 현재 없어요, 이제는? 그때 항고되었던 부분은 고검의 승인을 받아서 항고 기각되어서 종결된 것으로 알고 있고 지금 일부는 참고인중지 상태로 참고인 소재 불명인 상태입니다. 참고인 찾으려는 노력은 해 보셨습니까? 이게 한 2년 전에 처분된 사건입니다마는 최근 한겨레신문 언론보도를 계기로 저희가 검찰수사관까지 탐문을 통해서 소재 확인을 지금 하고 있습니다. 참고인중지 처분을 내렸을 때 허 전 회장이 뉴질랜드로 출국했잖아요. 그 뒤로 지금 안 돌아온 거예요? 항고 당시에 외국으로 출국해서 지금 외국에 체류 중인 것으로 알고 있습니다. 그러니까 국민들 입장에서는 도저히 그 상황을 받아들이기가 어렵지요.   허 전 회장 전 사위가 대표를 맡고 있던 건설사로부터 70억 원 채권을 넘겨받은 사건 지금 경찰에서 수사하고 있습니까? 용인에서 있었던 사건인데 서울중앙지검으로 가 있는 것으로 알고 있습니다. 지금은 서울중앙지검에 갔어요? 광주지검하고는 그러면 지금…… 강제집행면탈로 고소되어서 서울중앙지검에 있는 것으로 알고 있습니다.', 'context_summary_summary_q': '허재호 전 대주그룹 회장의 조세포탈 혐의에 대한 판결과 이에 따른 국세청의 추가 조사, 그리고 광주지검에서의 무혐의 결정에 대한 현재의 상황을 설명해 주십시오.', 'context_summary_summary_a': '허재호 전 대주그룹 회장의 조세포탈 혐의에 대한 판결은 광주고등법원에서 벌금 5억 원으로 결정되었습니다. 이에 서울지방국세청은 국세 63억 원 탈세 사실을 발견하고 고발했으며, 광주지검에서는 무혐의 결정을 내렸습니다. 현재 해당 사건은 종결된 것으로 알려져 있으며, 허 전 회장과 관련된 현재의 사건이 없거나 참고인 중지 상태로 진행 중인 것으로 알고 있습니다.', 'questioner_name': '백혜련', 'questioner_affiliation': '', 'questioner_position': '위원', 'question_comment': '모르세요, 허재호 전 대주그룹 회장 황제노역 사건? 그 허재호 전 대주그룹 회장이 2010년도에 재판을 받으면서 광주고등법원에서 조세포탈 혐의에 대해서 벌금도 엄청 깎이고 몸으로 때울 수 있는 환형유치 기간 역시 대폭 낮추면서 일당 5억 원으로 판결하면서 정말 황제노역이라는 신조어가 탄생하고 유전무죄의 극치를 보여 줬던 사건입니다.  그리고 이 사건에 대해서 온 국민들이 봐 주기 판결이라고 볼 수밖에 없었던 것이 허재호 회장의 선친이 목포지원장 출신의 판사, 여동생은 법무부 교정협의회중앙회장, 매제는 검사였지요. 그리고 사위는 광주지법의 판사 그리고 남동생은 전현직 판사들의 골프모임을 책임지는 법구회 총무, 이런 인적 네트워크로 되어 있는 상태에서 그런 판결이 내려졌기 때문에 더욱이나 이것이 정상적인 판결이라고 보기는 어려웠습니다.  그래서 이런 국민들의 분노가 솟구치니까 서울지방국세청에서 다시 조사해서 국세 63억 원을 탈세한 사실을 적발하고 그중에서 6억 8000만 원을 특정해서 허 전 회장을 고발했습니다.   그런데 결국은 광주 ...
# --------------------------------------------------
# Content:
#  context: 전작권 전환에 대해서 이야기하겠습니다.  지난번 12일 국방부 국정감사에서 전작권 전한에 대해서 ‘한미 양국 간에 합의된 사항이다. 그리고 미래연합군사령부 편성안도 한미군사위원회(MCM) 그리고 안보협의회(SCM)에서 승인을 받겠다’ 이렇게 말씀하셨잖아요, 그랬지요? 예. 그런데 결국 승인을 못 받았잖아요. 승인은 매티스 장관하고 저하고 합참에서 올라온 것을 가지고 검토를 다 했습니다. 그런데 금년도…… 그러면 장관과 매티스 장관하고 승인하면, 승인을 받으면 되는 건데 왜 이것을 1년 연기했어요? 연기를 한 것이 아니라 그것은 합참에서 하는 수준하고 장관이 하는 수준하고 다릅니다. 그래서 이것을 좀 더 발전시키고 전작권을 환수하더라도 그 이후의 보장을 더 단단히 해 놓는 그런…… 그러면 언제 승인받는 겁니까? 내년도 SCM에 다시 올리기로 했습니다. 그러니까 1년 걸리잖아요, 그러면. 왜 이렇게 말을 계속 돌리십니까. 결국 미래연합군사령부 편성안이 1년 늦어지면 전작권 전환도 또 그만큼 늦어지는 것 아니에요? 안보에는 빈틈이 없는 것이 더 중요하지 않겠습니까? 그러니까, 그 말씀 잘하셨어요. 제가 그 말씀 듣고 싶어서 그런 거예요. 주권국만 강조하지 말고, 대한민국의 국격만 강조하지 말고 대통령 공약이라고 해서 막 그렇게 밀어붙여서는 안 된다는 이야기지요. 바로 그런 자세로 임하라는 이야기입니다. 전작권 전환은 필요하지만 그러나 확고하게 정말 철저하게 준비해서 하는 게 더 맞는 것이지 않습니까? 예, 맞습니다. 그래서 이 얘기는 우리 문재인 정권이 갖고 있는 공통 인식입니다. NSC도 다 그렇게 얘기하고 있습니다. 한미연합사 부사령관이 나와서 그렇게 증언을 하셨잖아요, 그날. 또 지금 장관은 계속 그렇게 말씀하시는데 미국의 월스트리트 저널이 한 이야기 들었지요? ‘미국이 전작권을 포기할 뜻이 없다’ 그런 이야기를 하고 있고 ‘전작권 전환 문제가 양국 간의 갈등을 야기할 소지가 있다’ 그건 그냥 단순한 한 언론인의 말일 뿐입니까? 같이 공동
# Metadata:
#  {'filename': 'SRC_20대_2017_2017년10월31일_국정감사_국방위원회_0014(047504).xlsx', 'date': '2017년10월31일(화)', 'conference_number': '047504', 'question_number': '0014', 'meeting_name': '국정감사', 'generation_number': '20', 'committee_name': '국방위원회', 'meeting_number': '2017', 'session_number': '2017년10월31일', 'agenda': '감사개시', 'law': '', 'qna_type': '추출형', 'context': '전작권 전환에 대해서 이야기하겠습니다.  지난번 12일 국방부 국정감사에서 전작권 전한에 대해서 ‘한미 양국 간에 합의된 사항이다. 그리고 미래연합군사령부 편성안도 한미군사위원회(MCM) 그리고 안보협의회(SCM)에서 승인을 받겠다’ 이렇게 말씀하셨잖아요, 그랬지요? 예. 그런데 결국 승인을 못 받았잖아요. 승인은 매티스 장관하고 저하고 합참에서 올라온 것을 가지고 검토를 다 했습니다. 그런데 금년도…… 그러면 장관과 매티스 장관하고 승인하면, 승인을 받으면 되는 건데 왜 이것을 1년 연기했어요? 연기를 한 것이 아니라 그것은 합참에서 하는 수준하고 장관이 하는 수준하고 다릅니다. 그래서 이것을 좀 더 발전시키고 전작권을 환수하더라도 그 이후의 보장을 더 단단히 해 놓는 그런…… 그러면 언제 승인받는 겁니까? 내년도 SCM에 다시 올리기로 했습니다. 그러니까 1년 걸리잖아요, 그러면. 왜 이렇게 말을 계속 돌리십니까. 결국 미래연합군사령부 편성안이 1년 늦어지면 전작권 전환도 또 그만큼 늦어지는 것 아니에요? 안보에는 빈틈이 없는 것이 더 중요하지 않겠습니까? 그러니까, 그 말씀 잘하셨어요. 제가 그 말씀 듣고 싶어서 그런 거예요. 주권국만 강조하지 말고, 대한민국의 국격만 강조하지 말고 대통령 공약이라고 해서 막 그렇게 밀어붙여서는 안 된다는 이야기지요. 바로 그런 자세로 임하라는 이야기입니다. 전작권 전환은 필요하지만 그러나 확고하게 정말 철저하게 준비해서 하는 게 더 맞는 것이지 않습니까? 예, 맞습니다. 그래서 이 얘기는 우리 문재인 정권이 갖고 있는 공통 인식입니다. NSC도 다 그렇게 얘기하고 있습니다. 한미연합사 부사령관이 나와서 그렇게 증언을 하셨잖아요, 그날. 또 지금 장관은 계속 그렇게 말씀하시는데 미국의 월스트리트 저널이 한 이야기 들었지요? ‘미국이 전작권을 포기할 뜻이 없다’ 그런 이야기를 하고 있고 ‘전작권 전환 문제가 양국 간의 갈등을 야기할 소지가 있다’ 그건 그냥 단순한 한 언론인의 말일 뿐입니까? 같이 공동 기자회견을 하는데 그 월스트리트 저널 기자가 질문했는데 잘못 쓴 기사입니다. 그래요? 예.', 'context_summary_summary_q': "한미연합사 부사령관과 장관이 전작권 전환 관련 발언을 지속적으로 하고 있지만, 미국 월스트리트 저널이 '미국이 전작권을 포기할 뜻이 없다'라는 언론 보도를 내놓았습니다. 이러한 기사가 한미 간 갈등을 야기할 가능성은 어떻게 평가하시나요?", 'context_summary_summary_a': '해당 기사가 한미 간 갈등을 야기할 가능성은 낮아보입니다. 한미 연합사 부사령관과 장관의 발언이 진정성 있게 이루어지고 있으며, 양국 간의 협력과 의사소통을 강조하고 있습니다. 이로써 잘못된 보도가 한미 간 협력에 큰 영향을 미치지는 않을 것으로 기대됩니다.', 'questioner_name': '김동철', 'questioner_affiliation': '', 'questioner_position': '위원', 'question_comment': '한미연합사 부사령관이 나와서 그렇게 증언을 하셨잖아요, 그날. 또 지금 장관은 계속 그렇게 말씀하시는데 미국의 월스트리트 저널이 한 이야기 들었지요? ‘미국이 전작권을 포기할 뜻이 없다’ 그런 이야기를 하고 있고 ‘전작권 전환 문제가 양국 간의 갈등을 야기할 소지가 있다’ 그건 그냥 단순한 한 언론인의 말일 뿐입니까?', 'question_keyword': '한미연합사 부사령관,  증언,  미국,  월스트리트 저널,  전작권 포기,  전환 문제,  양국,  갈등,  언론인', 'answerer_name': '송영무', 'answerer_affiliation': '국방부', 'answerer_position': '장관', 'answer_comment': '같이 공동 기자회견을 하는데 그 월스트리트 저널 기자가 질문했는데 잘못 쓴 기사입니다.', 'answer_keyword': '공동 기자회견,  월스트리드 저널 기자,  질문,  기사'}
# --------------------------------------------------
# Content:
#  건설사업, 어촌종합개발사업 이 다섯 가지인데 사실은 거의 다 국가사업으로 해 줘야지 농특 예산에 넘어가는 것은 문제가 있다는 사항입니다.   정부 입장은 어때요? 이것을 꼭 지켜야 될 것하고 해 주면 안 되는 그런 사업이 있습니까? 경중은 있습니다. 경중은 있는데 위원회에서 이렇게 의견을 달아 주시면 저희들로서는 좋을 것 같습니다. 지방어항 건설사업을 국가사업으로 한다는 것은 내용은 모르겠는데 제목이 좀 이상하네요. 지금도 국비 80% 지원하는 것입니다. 특별한 것이 없으면…… 지방어항 건설사업은 이관은 하되 증액을 했으면 좋겠다는 말씀입니다. 왜냐하면 전국에 있는 지방어항이 314개인데 1년에 관리 예산이 353억밖에 되지 않습니다. 그러다 보니까 앞에 나와 있지만 28%밖에 완공이 안 되고 아주 저조합니다.   이것이 애초부터 295억 353억 해 가지고 몇백억 단위로 하는데 여기에 대한 추가재원이 필요한 게 아니고 전국 영세어민들에게 골고루 혜택이 가는 사업이기 때문에 이것을 대폭 증액을 해서, 예결위에 가서 삭감을 당할 때 당하더라도 이것은 증액을 해야 된다고 생각을 합니다.  왜냐하면 완공률이 전국이 28% 밖에 되지 않습니다. 그러니까 이것도 내년에 또 찔끔 1억씩 주면 2%, 3% 올라가는 수준밖에 안 되기 때문에 이것에 대해서 진지하게 토론을 해 주시면 좋을 것 같습니다.   애초에 예산 책정할 때 지방항이 소외되어 가지고 하다 보니까 필요성이 없어서가 아니라 매년 예산 배당을 이렇게 밖에 못 받는 것이에요. 지금 균특회계를 국가시행사업으로 재이관을 결의하면서 거기에 예산 증액까지 할 수가 있나요? 앞의 것을 다시 올려줘야지요. 그런 돈이 필요하기 때문에 이것은 농특회계로 이관해야 된다는 얘기지요. 그러니까 이것 자체가 국가시행사업으로 재이관하는 순간, 지방이 부담해야 될 20% 예산 자체를 국가가 부담하니까 사실상 그만큼 증액이 되는 것이에요. 증액이 되는데 또 증액한다면 무리니까 일단 이번에는 이관까지만 하고 다음에 증액을 하고 이렇게
# Metadata:
#  {'filename': 'SRC_17대_제250회_제3차_소위원회_농림해양수산위원회-예산안및결산심사소위원회_0001(032815).xlsx', 'date': '2004年11月22日(月)', 'conference_number': '032815', 'question_number': '0001', 'meeting_name': '소위원회', 'generation_number': '17', 'committee_name': '농림해양수산위원회-예산안및결산심사소위원회', 'meeting_number': '제250회', 'session_number': '제3차', 'agenda': '1. 2005년도예산안가. 해양수산부소관나. 해양경찰청소관2. 2005년도기금운용계획안가. 해양수산부소관', 'law': '', 'qna_type': '추출형', 'context': '다음에 국가균형발전특별회계에서 국가 시행 사업으로 재이관이 필요한 사업입니다. 삭감 예산에 대해서 좀 더 이야기를 하겠습니다.  새만금 해양환경영향조사 예산이 작년의 31억 5000만 원에서 금년에 34억 정도로 2억 5000이 증액되었습니다.   향후 방조제 완성을 염두에 두고 2억 5000을 증액한 것 같은데, 새만금 전체에 관한 논의도 있고 한데 해양환경영향조사에 이렇게 많은 돈이 드는지 의문일 뿐만 아니라 사업 전체에 대해서도 저희들이 예산을 감액했기 때문에 작년 수준으로 해서 감액합시다. 31억 5000만 원으로 2억 5000만 원은 조정할 필요가 있다고 생각합니다. 새만금 해양환경영향조사는 몇 년에 걸쳐서 하는 것입니까? 계속사업으로 하는 거예요? 이게 중요하잖아요. 계속사업입니다. 언제까지 하는 겁니까? 새만금 사업이 어떻게 되든 간에 수질 모니터링하고 개선사업은 해야 됩니다. 매해 이렇게 균분해서 주는 거예요? 사업계획을 검토해서 반영하는 것입니다. 34억은 내년에 꼭 필요한 사업인가요, 아니면 융통성이 있는 돈인가요? 필요한 사업을 정한 것입니다. 용역비면 계약을 하고, 예를 들어서 34억짜리 사업을 10억만 주면 24억에 대한 것은 못 하잖아요. 그러니까 꼭 필요한 예산인지 아니면 삭감해도 되는 예산인지 이야기해 보세요. 해양정책국장입니다.  새만금 사업 예산 34억은 꼭 필요한 예산입니다. 왜 필요해요? 이번에 새만금에 대한 연구조사가 있습니다.   지난번에 국무조정실에서 정리가 되어서 저희가 방조제 내ㆍ외해에 대한 모니터링, 피해 최소화 방안, 해서 거기에 대한…… 당신들이 성의 있게 예산에 임하려고 하면, 박 위원님이 이런 지적을 하실 때 ‘항목별로 이렇게이렇게 해서 34억이 필요합니다’ 이런 데이터를 주셔야 삭감하지 못하고 그러지. 이게 흥정해서 되는 예산인지 아닌지…… 15억 정도 줘도 용역할 수 있겠어요? 그러면 19억은 자르고 드릴까요?  그런 것을 정확한 자료를 가지고 와서 위원님들을 설득할 생각을 해야지…… 새만금 사업이, 방파제 공사가 완공되었을 때 민물이 차단될 것 아닙니까? 그랬을 때 급격한 환경변화가 있을 것을 예상해서 환경조사 비용을 책정한 것 같은데, 지금 저희들이 방향을 어느 정도 정해서 결정한 사항이 일부 있기 때문에 그런 차원에서…… 내가 보니까 금액도 34억 같으면 적은 금액이 아니잖아요? 일부 조정할 필요가 있다…… 그게 새만금에만 해당되는 예산인가요? 매년 34억이에요? 매년이고, 작년도에는 31억이었습니다. 그러면 31억 5000만 원만 하면 되겠네. 원래 설치해야 할 부위가 있습니다. 그런데 그 부위를 작년도에 넣지 못했기 때문에 올해는 좀 넣도록…… 연구기관에서 조사되었던 결과들은 있어요? 예, 있습니다. 그것도 위원님들께 제출하도록 하겠습니다. 차관님 한 말씀만 덧붙입시다.   어떻게 1개 만의 조사비용이 31억이라 하고, 전체적인 해양환경조사에서는 예산이 얼마로 되어 있지요? 16억입니다. 전체적으로 우리나라 뱀장어 생산량이 얼마나 돼요? 뱀장어 이야기는 그만하시고…… 감액하는 것은 기백억짜리를 감액해야지…… 박 위원님의 문제 제기는 타당합니다.   그런데 그것을 손을 대려면 10억 20억은 해야지, 몇 억 그런 것은 손 댈 필요가 없어요. 그것을 판단하셔야 됩니다. 그것은 그렇게 하고, 해양 심층수 다목적 이용 사업을 강원도 고성에 해 가지고 2004년도에 50억이 반영되었고 내년 예산은 32억으로 줄었습니다.  일본 같은 경우에는 해양 심층수의 개발이 많이 되어 있는 것으로 알고 있고 이 사업의 개발 필요성은 충분히 있는데, 문제는 이것이 민간 차원에서 되어야 할 사업이 아닌가……  이것을 국가에서 돈을 들여서 계속 예산을 짜서 한다는 것은 근본적으로 낭비적인 요소가 많다, 32억인데 이것은 사업의 성격으로 보아서 이 금액 전체를 삭감해서 민자사업으로 완전히 돌려서 할 필요가 있고, 국가에서 예산 지원을 하는 것은 맞지 않다고 봅니다. 설명 올리겠습니다.   일단 대체토론 때 논의되지 않았기 때문에 구체적으로 설명드리기에는 어려움이 있습니다마는 설명 올리겠습니다.   심층수 개발에 관해서는 위원님 말씀에 인식을 같이 합니다. 이것은 정부가 개발할 사항은 절대 아니고 민간 사업화시켜야 합니다.   다만, 그 단계까지 가기 위해서는 연구개발은 민간이 투자해 가지고는 안 됩니다. 그래서 정부는 연구개발 기초까지만 하고 그 이후에는 민간이 투자하는 쪽으로 가게 되어 있습니다. 해양 심층수 개발하면 누가 이익을 봐요? 어민들이 봐요, 농민들이 봐요? 국민 전체가 다 이익을 보지요 어민이나 농민들과는 상관없는 사업자지요. 어민들이 이익 보는 데에는 예산을 제대로 배정하지 않으면서 특정 업자가 이익 보는 데에다 그렇게 해도 돼요? 분명히 어민도 이익 봅니다. 참고해야 될 것이, 일본에서 엉터리 해양 심층수가 마구 들어와서 강남 일대에 엄청나게 팔리고 있어요. 그런데 우리 정부가 지금 제대로 대응도 못 하고 있고…… 내가 일본 해양 심층수를 전부 샘플링해서 조사해 보니까 우리가 식음수로서 쓸 수 없는 물들이 엄청나게 많았단 말이지.  그것이 보도자료 나가고 나니까 그 녀석들이 수십억 손해배상 청구를 하고 이렇게 내가 시달리고 기자들도 시달리고 했는데, 이것은 정부가 분명한 입장을 세워 줘야 합니다. 심층수를 개발해서 어떻게 할 것인지를 해 줄 필요가 있다는 이야기예요.   엉터리 해양 심층수를 일본에서 가지고 들어와서 굉장히 몸에 좋은 것으로 마구 팔고 있는데 물의 함량 기준들을 보면 식음수로서 적절치 못 하다는 말이에요. 그런데 해수부가 아무 대응도 못 하고 있는데, 그에 대해서는 정책적으로 우리가 어떻게 접근할 것인지 판단해야 됩니다. 2010년까지 해서 총 사업비가 250억인데 2003년도에 38억 투자되었고, 2004년도에 50억 예산을 다 썼는지 모르겠는데 이런 정도의 사업은 당연히 민자와 같이 가거나 해서 처음부터 사업이 짜여져야지 이것을 국가로 해서 어떻게 다시 민자로 이관할 것인지, 사업에 대한 프로젝트가 근본적으로 잘못된 거예요. 민자 계획이 다 되어 있습니다. 이게 해양연구원의 심층수 개발팀에서 쓰는 돈 아니에요? 해양연구원은 우리 해양수산부 소속도 아니에요.  이것 다 깎으세요. 그런데 보니까 계속비 사업으로 깎아도 안 될 사업이네.  계속비 사업이면 처음에 사업을 하지 못하도록 했어야지 2003년까지 진행시키고 이제 와서 예산을 잘라 버리면 사업이 되지를 않지.  문제는 심층수 개발이 필요한가 안 한가의 문제인데, 필요하다고 생각하면 일을 할 수 있도록 해 주어야 되는 것이고 필요하지 않다고 하면 이제라도 삭감해야 되는 것이지, 계속비 사업은 안정성이 있어야지 국회가 바뀌고 상임위가 바뀌었다고 해서 연차적으로 투자해서 하는 사업을 못 하게 한다는 것은 나는…… 작년도 사업 집행은 어떻게 되었어요? 작년도 사업비는 거의 다 집행되고 있습니다.   연구센터를 짓는 예산이 20억이었는데 지난번에 착공해서 지금 현재 공사 진행 중에 있고, 그래서 예정대로 내년 5월에 연구센터는 완공됩니다.   그 외에 저희가 연구조사사업이 있습니다. 왜 그 연구 주체가 해양연구원이 되어야 해요? 그래서 저희가 연구 기초조사를 하고 있고, 그리고 전체적인 법제연구도 굉장히 필요합니다. 그 작업을 지난 2월에 국회에서 공청회까지 ...
# --------------------------------------------------
# Content:
#  쪽에서는 당론을 더 모아야 되겠다는 쪽으로 이야기를 하셨고요.  두 번째, 기타 제도개선 부분에 있어서는 지금 대부분 논의가 많이 진척이 되어 있습니다. 그리고 지금 남은 꼭지가 한 세 꼭지 정도인데 이거 설명드리면 되고요.  여기에 앞서서 지금 정부 쪽에서 그동안 사실상의 수수료 인하를 위해서 많은 노력을 했고 또 정부 쪽 의견이 있는 것 같으니까 그동안의 여전법을 둘러싼 정부 측의 노력이랄까 이런 부분을 조금 이야기를 들으시고요. 제도개선 세 꼭지 남았다는 거 먼저 해 버리면 어때요? 괜찮습니다. 그거 하고 정부 쪽에서 여러 가지 준비한 게 있다니까, 그럼 나머지 세 꼭지 하십시다.   몇 페이지입니까? 29쪽부터 하시면 됩니다.   잠깐 앞의 것 리마인드 안 시켜도 되겠지요? 예. 예, 6번 항목입니다.  지금 현재 여신전문금융회사의 부수업무 범위를 사실상으로는 확대하는 내용입니다. 부수업무 규정을 현재 포지티브 방식에서 네거티브 방식으로 해서 조금 확대하고자 하는 내용입니다.  그래서 현행하고 개정안 차이를 보면 지금 현재 김용태 의원안에 46조의2를 신설해서 여신전문금융업자가 소유하고 있는 인력ㆍ자산 또는 설비를 활용하는 업무를 영위하고자 하는 경우에는 7일 전까지 이를 신고하도록 하는 내용 등을 하고 있습니다.   그다음에 2항을 보시면 각호의 경우에는 부수업무의 영위를 제한하거나 시정을 명할 수 있도록 하는 내용도 되어 있습니다. 이 부분은 부수업무 규정을 지금 현재와 같이 말고 조금 더 확대할 수 있도록 네거티브 방식으로 변경할 수 있는 내용으로 대체적으로 타당합니다마는 정부 쪽에서는 이 부분에 대해서 의견이 있는 걸로 보입니다. 정부 쪽 의견을 좀 말씀해 주세요.  부수업무라는 게 대체로, 예를 들면 어떤 걸 말하는 겁니까? 카드회사들이 여행업이랄까 통신판매라든가 이런 업무를 지금 하고 있습니다. 그런데 그거를 어떻게 한다고요? 예, 지금은…… 그걸 확대한다는 소리 아니에요?  사실은 여신전문업법에 있어서 부수업무가 확실시 안 되어 있기
# Metadata:
#  {'filename': 'SRC_18대_제285회_제6차_소위원회_정무위원회-법률안심사소위원회_0001(039059).xlsx', 'date': '2009年12月29日(火)', 'conference_number': '039059', 'question_number': '0001', 'meeting_name': '소위원회', 'generation_number': '18', 'committee_name': '정무위원회-법률안심사소위원회', 'meeting_number': '제285회', 'session_number': '제6차', 'agenda': '1. 소비자생활협동조합법 전부개정법률안(이사철 의원 대표발의)(계속) 2. 소비자생활협동조합법 일부개정법률안(김종률 의원 대표발의)(계속) 3. 소비자생활협동조합법 일부개정법률안(우윤근 의원 대표발의)(계속) 4. 소비자생활협동조합법 일부개정법률안(정부 제출)(계속) 5. 독점규제 및 공정거래에 관한 법률 일부개정법률안(정부 제출)(계속) 6. 여신전문금융업법 일부개정법률안(장세환 의원 대표발의)(계속) 7. 여신전문금융업법 일부개정법률안(최구식 의원 대표발의)(계속) 8. 여신전문금융업법 일부개정법률안(김용구 의원 대표발의)(의안번호 1021)(계속) 9. 여신전문금융업법 일부개정법률안(김용구 의원 대표발의)(의안번호 4625)(계속)10. 여신전문금융업법 일부개정법률안(이성헌 의원 대표발의)(계속)11. 여신전문금융업법 일부개정법률안(권택기 의원 대표발의)(계속)12. 여신전문금융업법 일부개정법률안(박선숙 의원 대표발의)(계속)13. 여신전문금융업법 일부개정법률안(이정희 의원 대표발의)(계속)14. 여신전문금융업법 일부개정법률안(조문환 의원 대표발의)(계속)15. 여신전문금융업법 일부개정법률안(이진복 의원 대표발의)(의안번호 3067)(계속)16. 여신전문금융업법 일부개정법률안(이진복 의원 대표발의)(의안번호 5433)(계속)17. 여신전문금융업법 일부개정법률안(이진복 의원 대표발의)(의안번호 5449)(계속)18. 여신전문금융업법 일부개정법률안(박보환 의원 대표발의)(계속)19. 여신전문금융업법 일부개정법률안(김동철 의원 대표발의)(계속)20. 여신전문금융업법 일부개정법률안(장제원 의원 대표발의)(계속)21. 여신전문금융업법 일부개정법률안(고승덕 의원 대표발의)(계속)22. 여신전문금융업법 일부개정법률안(김용태 의원 대표발의)(계속)23. 여신전문금융업법 일부개정법률안(박종희 의원 대표발의)(의안번호 4632)(계속)24. 여신전문금융업법 일부개정법률안(박종희 의원 대표발의)(의안번호 5500)(계속)25. 여신전문금융업법 일부개정법률안(박종희 의원 대표발의)(의안번호 5910)(계속)26. 여신전문금융업법 일부개정법률안(김종률 의원 대표발의)(계속)', 'law': '소비자생활협동조합법 전부개정법률안;독점규제 및 공정거래에 관한 법률 일부개정법률안;여신전문금융업법 일부개정법률안', 'qna_type': '추출형', 'context': '이것은 나중에 하지요. 그래, 이건 민주당 쪽의 요청도 있으니까 이거는 나중에 하십시다. 이걸 계속 ‘나중에, 나중에’ 하면 안 하는…… 아니, 다른 거 하고. 아니, 하는데 우선 지금 금융위원회의 여신전문법을 처리해야 되기 때문에…… 순위가 약간 뒤로 밀리는 거는 괜찮은데…… 순위만 잠깐 바꾸는 겁니다, 여전법을 빨리 처리해야 되기 때문에. 금융지주회사법이 통과되어 있는 상태이기 때문에 이 부분에 대한 논의도 있어야지요. 예, 알겠습니다.   다음번 소위 때는 이거 하겠습니다.   우리가 합의하는 거야 여야 의논을 충분히 한 다음에 하지만 하여튼 논의 자체는 하도록 하겠습니다, 다음번에. 오늘은 금융위원회 관련법을 하도록 하겠습니다.   수고하셨습니다. 예, 고맙습니다. 다음번에는 보험협회 의견 받아 오고 그다음에 공정거래법 할 수 있도록 준비해 주세요. 예, 알겠습니다. 수고하셨습니다.   금융위원회 들어오라고 하세요.  자, 시작할까요?  그러면 여신전문금융업법 일부개정법률안에 대해서 심사를 다시 시작하겠습니다.  전문위원이 회의 진행 순서에 대해서 좀 의견을 제시해 주십시오. 예, 우선 여신전문금융업법은 지난번까지 위원님들이 잘 아시다시피 크게 두 가지 파트입니다. 하나는 수수료 인하와 관련된 여러 가지 의견들, 법안 내용들이 나와 있고요. 또 하나는 기타 제도개선이라는 이름으로 21쪽 이하에 나와 있습니다.   그런데 앞쪽을 우선 먼저 말씀을 드리면 지난번까지 논의된 바에 의하면 수수료상한제, 그다음에 19조1항을 삭제하는 부분 또 공동망 이용 등 여러 가지 의견이 있으셨고 또 한나라당 쪽에서는 당론을 더 모아야 되겠다는 쪽으로 이야기를 하셨고요.  두 번째, 기타 제도개선 부분에 있어서는 지금 대부분 논의가 많이 진척이 되어 있습니다. 그리고 지금 남은 꼭지가 한 세 꼭지 정도인데 이거 설명드리면 되고요.  여기에 앞서서 지금 정부 쪽에서 그동안 사실상의 수수료 인하를 위해서 많은 노력을 했고 또 정부 쪽 의견이 있는 것 같으니까 그동안의 여전법을 둘러싼 정부 측의 노력이랄까 이런 부분을 조금 이야기를 들으시고요. 제도개선 세 꼭지 남았다는 거 먼저 해 버리면 어때요? 괜찮습니다. 그거 하고 정부 쪽에서 여러 가지 준비한 게 있다니까, 그럼 나머지 세 꼭지 하십시다.   몇 페이지입니까? 29쪽부터 하시면 됩니다.   잠깐 앞의 것 리마인드 안 시켜도 되겠지요? 예. 예, 6번 항목입니다.  지금 현재 여신전문금융회사의 부수업무 범위를 사실상으로는 확대하는 내용입니다. 부수업무 규정을 현재 포지티브 방식에서 네거티브 방식으로 해서 조금 확대하고자 하는 내용입니다.  그래서 현행하고 개정안 차이를 보면 지금 현재 김용태 의원안에 46조의2를 신설해서 여신전문금융업자가 소유하고 있는 인력ㆍ자산 또는 설비를 활용하는 업무를 영위하고자 하는 경우에는 7일 전까지 이를 신고하도록 하는 내용 등을 하고 있습니다.   그다음에 2항을 보시면 각호의 경우에는 부수업무의 영위를 제한하거나 시정을 명할 수 있도록 하는 내용도 되어 있습니다. 이 부분은 부수업무 규정을 지금 현재와 같이 말고 조금 더 확대할 수 있도록 네거티브 방식으로 변경할 수 있는 내용으로 대체적으로 타당합니다마는 정부 쪽에서는 이 부분에 대해서 의견이 있는 걸로 보입니다. 정부 쪽 의견을 좀 말씀해 주세요.  부수업무라는 게 대체로, 예를 들면 어떤 걸 말하는 겁니까? 카드회사들이 여행업이랄까 통신판매라든가 이런 업무를 지금 하고 있습니다. 그런데 그거를 어떻게 한다고요? 예, 지금은…… 그걸 확대한다는 소리 아니에요?  사실은 여신전문업법에 있어서 부수업무가 확실시 안 되어 있기 때문에 영역 없이 자꾸 늘어나는 게 문제인데 거기에 대해서 더 확대를 한다고? 아니요, 그게 아니고 지금은 이게 포지티브 방식으로 되어 있습니다. 어떠어떠한 업무만 부수업무로 한다 이렇게 되어 있는데요. 이거를 다른 법령들, 자본시장법이라든지 이런 법령의 규정체계나 똑같이 이걸 네거티브 방식으로 바꿔 가지고요.  그래서 다른 법에서, 가령 예를 들어서 다른 보험업법이라든지 은행법에서 카드업자가 할 수 있다 이렇게 규정하는 업무는 겸영업무로서 저희가 할 수 있게끔 하고 나머지는 종전에 하던 대로 조직이나 인력을 활용해서 할 수 있는 것은 부수업무로 할 수 있게끔 그렇게…… 그러니까 굉장히 늘어난다는 소리지요. 그리고 뭐가 뭔지 모르게 된다는 소리지요. 아닙니다. 범위는 약간 늘어나긴 하겠지만요, 지금 전체적으로…… 그러니까 뭐가 늘어나는지 얘기해 보세요. 이랬을 경우에 늘어나는 것에 대해서 예를 쭉 들어 보시라고요.  이렇게 해 놓으면 거기하고 달리 이거를 완전히 네거티브, 뭐 뭐 빼놓고는 할 수 있다 해 놓으면 굉장히 제한이 안 되기 때문에 나는 문제 있다라고 보는데? 이렇게 포지티브 방식을 네거티브 방식으로 바꾸는 데 필요성이 뭔지를 좀 설명해 보세요. 포지티브 방식으로 하게 되면 회사들의 영업이 굉장히 많이 제약이 됩니다. 그러니까 모든 업무를, 자기네가 새로운 상품을 만든다든지 이럴 때 저희가 다 일일이 법을 개정해서 이것은 할 수 있다, 없다 하는 것을 다 정해 줘야 되기 때문에 지금 모든 금융 ...
# --------------------------------------------------
# Content:
#  그렇지 않습니다. 그러면 대검 형사부장이 저한테 거짓말한 것입니까? 보통 대검이나 검찰에 장관의 지시사항 전달은 검찰국장을 통해서 하게 되는데 이 사안도 검찰국장을 통해서 신속, 지난번 국회에서 답변드렸던 것과 같은 내용의 지시를 검찰국장을 통해서 했습니다. 제가 대검 쪽에서 질문했을 때 서울중앙지검 검사장은 대검의 형사부장을 통해서 얘기를 들은 것밖에 없다고 얘기했고, 대검 형사부장한테는 특별히 장관한테 들은 얘기가 없다는 얘기를 제가 확인했습니다.   그러면 서울중앙지검장한테는 왜 검찰국장이나 이런 사람들이 얘기하지 않고 대검 형사부장이 얘기를 해서 들었다고, 그것밖에 없었다고 얘기했고, 대검 형사부장은 특별히 장관한테 들은 바가 없다고 그랬어요. 장관이 대검 형사부장이나 서울중앙검사장에게 직접 지시는 하지 않습니다. 알겠습니다. 검찰국장을 통해서 대검에 지시하는 것이기 때문에 형사부장의 언급에 대해서는 제가 잘, 정확히 파악을 못 했습니다. 그럼에도 불구하고 지금 특별히 수사가 진행되지는 않고 있지요?   이정현 당 대표 소환했습니까? 아직 소환하지는 않은 것으로 알고 있습니다. 녹취록이 다 공개되었고, 온 국민이 그 녹음파일을 다 들었어요. 그럼에도 불구하고 지금 당 대표 소환 안 되고 있는데……  제가 봤을 때 야당 당 대표 같은 경우에는 선거법 위반 혐의로 과감하게 기소하고, 여당 당 대표의 경우에는 국가기구인 세월호특조위가 고발하고 그 증거가 되는 녹취록이 다 공개되어도 제대로 조사가 안 이루어지고 있다, 좀 이상하지 않습니까? 검찰에서 수사 진행 경과에 따라서 조사를 진행할 것으로 알고 있습니다. 이번에 철도파업 관련돼서 질문을 드리겠습니다.    (영상자료를 보며)  법무부가 지난달 27일 날 국무조정실이 주재한 철도파업 관련대책 관계기관회의에 참석해서 배포한 것으로 보이는 문건이 있어요. 언론에도 보도가 됐는데, 이 문건에는 ‘파업목적이 근로조건과 관련되어 있다고 볼 여지가 있어서 불법성 여부는 신중히 접근할 필요가 있다’라고 되어
# Metadata:
#  {'filename': 'SRC_20대_2016_2016년10월17일_국정감사_법제사법위원회_0003(046535).xlsx', 'date': '2016년10월17일(월)', 'conference_number': '046535', 'question_number': '0003', 'meeting_name': '국정감사', 'generation_number': '20', 'committee_name': '법제사법위원회', 'meeting_number': '2016', 'session_number': '2016년10월17일', 'agenda': '감사개시', 'law': '', 'qna_type': '추출형', 'context': '서울 은평갑 박주민 위원입니다.  우 수석이 민정수석의 자리에 있으면서 우 수석에 대한 수사가 제대로 이루어질 것이라고 믿는 국민은 단 한 분도 없을 것입니다.   오늘 이 문제에 대해서 저도 거론하고 싶지만 다른 위원님들께서 집중적으로 거론해 주실 것이기 때문에 저는 잠깐 다른 내용을 질의하도록 하겠습니다.  장관님, 이정현 새누리당 대표가 지난 2014년 4월 30일 날 당시 KBS 보도국장이었던 김시곤에게 전화해서 뉴스의 교체를 요구했고, 실제로 그래서 심야뉴스에서 빠진 바 있었고, 이런 내용이 김 전 국장에 의해서 폭로가 됐었고, 특히 녹음파일까지 공개가 됐습니다.   그래서 세월호특조위가 지난 6월 28일 날 새누리당 이정현 대표에 대해서 방송법 위반했다면서 검찰에 고발했고, 세월호 특별법에 따르면 이러한 고발 건은 3개월 내에 처리되도록 되어 있습니다. 잘 알고 계시지요? 예, 알고 있습니다. 그래서 제가 9월 20일 날 대정부질문을 통해서 다른 사람도 아닌 바로 장관께 ‘어떻게 할 계획이냐?’라고 질문하자 장관께서 뭐라고 얘기했느냐 하면 ‘법과 원칙에 따라 신속하고 철저히 수사하도록 검찰을 지휘 감독하겠다’라고 답변을 하셨습니다.   그래서 제가 대검찰청 국감을 하면서 확인을 해 봤어요. ‘장관께서 특별히 뭐라고 하신 바가 있느냐?’, 답변이 뭐라고 나왔습니까? 답변이 뭐라고 나왔을까요? 아무것도 하신 게 없더군요.   대정부질문 했을 때 온 국민 앞에서 법과 원칙에 따라 신속하게 수사하도록 하겠다고 답변하셨는데, 대검에 가서 확인해 보니까 장관께서 하신 일은 아무것도 없었습니다. 그렇지 않습니다. 그러면 대검 형사부장이 저한테 거짓말한 것입니까? 보통 대검이나 검찰에 장관의 지시사항 전달은 검찰국장을 통해서 하게 되는데 이 사안도 검찰국장을 통해서 신속, 지난번 국회에서 답변드렸던 것과 같은 내용의 지시를 검찰국장을 통해서 했습니다. 제가 대검 쪽에서 질문했을 때 서울중앙지검 검사장은 대검의 형사부장을 통해서 얘기를 들은 것밖에 없다고 얘기했고, 대검 형사부장한테는 특별히 장관한테 들은 얘기가 없다는 얘기를 제가 확인했습니다.   그러면 서울중앙지검장한테는 왜 검찰국장이나 이런 사람들이 얘기하지 않고 대검 형사부장이 얘기를 해서 들었다고, 그것밖에 없었다고 얘기했고, 대검 형사부장은 특별히 장관한테 들은 바가 없다고 그랬어요. 장관이 대검 형사부장이나 서울중앙검사장에게 직접 지시는 하지 않습니다. 알겠습니다. 검찰국장을 통해서 대검에 지시하는 것이기 때문에 형사부장의 언급에 대해서는 제가 잘, 정확히 파악을 못 했습니다. 그럼에도 불구하고 지금 특별히 수사가 진행되지는 않고 있지요?   이정현 당 대표 소환했습니까? 아직 소환하지는 않은 것으로 알고 있습니다. 녹취록이 다 공개되었고, 온 국민이 그 녹음파일을 다 들었어요. 그럼에도 불구하고 지금 당 대표 소환 안 되고 있는데……  제가 봤을 때 야당 당 대표 같은 경우에는 선거법 위반 혐의로 과감하게 기소하고, 여당 당 대표의 경우에는 국가기구인 세월호특조위가 고발하고 그 증거가 되는 녹취록이 다 공개되어도 제대로 조사가 안 이루어지고 있다, 좀 이상하지 않습니까? 검찰에서 수사 진행 경과에 따라서 조사를 진행할 것으로 알고 있습니다. 이번에 철도파업 관련돼서 질문을 드리겠습니다.    (영상자료를 보며)  법무부가 지난달 27일 날 국무조정실이 주재한 철도파업 관련대책 관계기관회의에 참석해서 배포한 것으로 보이는 문건이 있어요. 언론에도 보도가 됐는데, 이 문건에는 ‘파업목적이 근로조건과 관련되어 있다고 볼 여지가 있어서 불법성 여부는 신중히 접근할 필요가 있다’라고 되어 있습니다.   그리고 그 이틀 뒤인 29일 날 환노위 국감에서 중앙노동위원회가 ‘이번 공공부문 파업에 돌입한 모든 노동조합은 정상적인 조정대상으로서 노동위원회의 조정 절차를 거쳤다’라고 밝혔습니다.   법무부의 애초의 입장도 이 불법성 여부는 신중히 접근해야 된다고 했고, 그 이틀 뒤인 환노위 국감에서 중앙노동위원회가 모든 조정 절차 걸쳤다라고 입장을 밝혔습니다.  그런데 지난 13일 날 갑자기 국무조정실장 주재로 열린 회의에서는 파업 주동자를 신속하게 사법처리하겠다라고 결정을 하고 철도공사가 고소한 19명에 대해서 사법처리 신속하게 진행하겠다라는 입장을 밝혔습니다.   29일 환노위 국감에서 중노위가 얘기했던 것 들으신 적 있어요? 모든 조정 절차를 거쳤다라고 중노위가 입장 밝혔던 것 확인하셨습니까? 그 부분에 대해서는 제가 확인을 못 했습니다. 중노위나 법무부 애초의 입장에서는 이 파업은 불법파업이 될 수가 없어요. 그런데도 지금 이 파업을 불법이다라고 얘기하고 철도공사가 고소한 19명에 대해서 사법처리하겠다라고 입장을 밝혔습니다.  이것은 합법파업을 불법으로 얘기하는 것이라서 오히려 정부가 불법적인 행위하는 거예요, 제가 봤을 때는. 어떻게 생각하십니까? 당시 철도노조 파업과 관련해서 여러 부처에서 모여서 실무자들이 다양한 의견을 교환한 것으로 알고 있는데, 당시 회의는 실무 차원에서 비공개로 진행되었던 것입니다. 그래서 그 회의 내용에 대해서 언급하는 것은 좀 적절치 않다고 생각을 하는데…… 아니, 중노위 결정을 지금 정면으로 반박하고 있는 거잖아요, 법무부가? 지금 현재 그런데, 이 철도 파업과 관련해서는 불법 여부 등에 대해서 수사가 진행되거나 수사가 예상되는 사안입니다. 그렇기 때문에 이에 대해서 어떤 법적 평가를 내린다는 것은 적절치 않다고 생각합니다. 그러면 지금 현재까지 법무부는 이 철도 파업에 대한 법적 평가를 내릴 단계가 아니다? 검토하고 있다? 예, 지금 수사가 진행 중이기 때문에…… 따라서 이것을 단순히 불법파업이라고 규정하고 사법처리를 신속하게 진행하겠다는 것은 사실과 다르다? 지금 수사가 진행 중입니다. 수사가 진행 중이니까 수사를 종료를 해야만 그 사안을 명확히 규정할 수 있을 것입니다.    (발언시간 초과로 마이크 중단)    (마이크 중단 이후 계속 발언한 부분) 그러니까 제가 여쭙잖아요.  정부가 이 파업을 불법파업으로 규정하고 사법처리를 신속하게 진행하겠다라는 것은, 그런 입장을 냈던 것은 사실과 다르다? 사법처리를 신속하게 하겠다라고 한 적은 아마 없는 것으로 알고 있습니다. 수사를 신속하게 진행하겠다는 취지로 아마 발표된 것으로 알고 있습니다.', 'context_summary_summary_q': '국무조정실장 주재 회의에서는 철도파업 주동자에 대한 신속한 사법처리를 결정했는데, 이에 앞서 중앙노동위원회는 모든 조정 절차를 거친 것으로 밝힌 바 있습니다. 이 두 가지 입장의 차이에 대해 어떻게 설명하실 것인가요?', 'context_summary_summary_a': '국무조정실장 주재 회의에서의 결정과 중앙노동위원회의 입장 차이에 대해서는 구체적인 확인이 필요한 부분입니다. 두 기관 간의 의견 조율 및 상황에 대한 추가 정보가 필요하며, 더 자세한 내용을 확인하기 위해 조사를 실시할 것입니다.', 'questioner_name': '박주민', 'questioner_affiliation': '', 'questioner_position': '위원', 'question_comment': '이번에 철도파업 관련돼서 질문을 드리겠습니다.    (영상자료를 보며)  법무부가 지난달 27일 날 국무조정실이 주재한 철도파업 관련대책 관계기관회의에 참석해서 배포한 것으로 보이는 문건이 있어요. 언론에도 보도가 됐는데, 이 문건에는 ‘ ...
# --------------------------------------------------
# Content:
#  하여금 조사토록 하게 되고, 일종의 협업시스템이고요. 저희가 한 번 걸러주고, 실무적으로 한 번 도와주고 이런 시스템이라고 보시면 되겠습니다. 제가 지금 왜 말씀드리냐면 여기 협의회 수정안 37조의3 제1항에 ‘조정을 권고할 수 있다’ 했잖아요? 예, 그렇습니다. 이것도 사실은 이게 공정거래법 대상이 안 되려고 그러면요 공정거래법에 근거가 있어야 됩니다. 이래 놓고 나서, 조정을 권고해 놓고 나서 그렇게 따라서 가면 그 자체가 공정거래법 대상이에요. 그래서 제가 지금 이야기하는 겁니다. 당초에는 시정권고로 돼 있어서 조정으로 바꾼 것이고요.
# Metadata:
#  {'filename': 'SRC_20대_제356회_제1차_소위원회_법제사법위원회-법안심사제2소위원회_0008(048041).xlsx', 'date': '2018년2월27일(화)', 'conference_number': '048041', 'question_number': '0008', 'meeting_name': '소위원회', 'generation_number': '20', 'committee_name': '법제사법위원회-법안심사제2소위원회', 'meeting_number': '제356회', 'session_number': '제1차', 'agenda': '6. 물류정책기본법 일부개정법률안(안호영 의원 대표발의)', 'law': '의료법 일부개정법률안;식품등 기부 활성화에 관한 법률 일부개정법률안;영유아보육법 일부개정법률안;화물자동차 운수사업법 일부개정법률안;감정평가 및 감정평가사에 관한 법률 일부개정법률안;물류정책기본법 일부개정법률안;유선 및 도선 사업법 일부개정법률안;승강기시설 안전관리법 전부개정법률안;자본시장과 금융투자업에 관한 법률 일부개정법률안;군복 및 군용장구의 단속에 관한 법률 일부개정법률안;고압가스 안전관리법 일부개정법률안;산림보호법 일부개정법률안;수산업․어촌 발전 기본법 일부개정법률안;수산업협동조합법 일부개정법률안;해운법 일부개정법률안;공공기관의 운영에 관한 법률 일부개정법률안;국제과학비즈니스벨트 조성 및 지원에 관한 특별법 일부개정법률안;연구개발특구의 육성에 관한 특별법 일부개정법률안;산업기술연구조합 육성법 일부개정법률안;위치정보의 보호 및 이용 등에 관한 법률 일부개정법률안;양육비 이행확보 및 지원에 관한 법률 일부개정법률안', 'qna_type': '추출형', 'context': '전문위원, 어떻습니까? 위원님께서 지난번에도 그 비슷한 논지로 말씀을 주셨던 걸로 알고 있습니다. 다만 이 부분과 관련돼서 아까도 보고 올렸지만 정부 차원에서 만든 협의안의 내용이기 때문에 지금 주신 말씀과…… 저는 이게 법체계상으로 문제가 있다고 봅니다. 이렇게 되면 지금 공정거래법의 대상에서 제외되는 것이 금융위 소관입니다. 나머지는 다 해당이 되거든요. 물류산업 분야는 계약 주체 간의 갑을관계가 다양하고 이로 인해서 현실적으로 횡포가 많이 벌어지고 있습니다. 그래서 시장에서 물류당국이 사전적으로 조정할 수 있는 장치를 마련해 주고자 이런 법안을 마련했는데요.  예를 들어서 저희가 11월 2일 날 창원터널 화물차 사고가 있었는데요 그게 화주 등이 화물차 기사에게 과적을 요구한 내용입니다. 그리고 본래 계약상 업무 외에 상하차, 컨테이너 용기 청소 등 추가적인 직무상의 업무를 요구하고 있는 게 현실이고요. 그다음에 운임단가와 관련해서도 화주 또는 물류 대기업이 일방적으로 계약단가 통보 및 계약 후에도 일방적으로 운임 변경을 요청하고 있습니다. 그래서 이것을 전체적으로 공정거래법에 적용하는 것보다는 현실적으로 물류 분야에서…… 공정거래법 대상하고 지금 이야기하시는 부분하고 조금 안 맞을 수가 있습니다. 제 이야기는 법의 적용 대상이 조금 차이가 있는 것 같습니다. 그래서 이 부분은 공정거래법상의 여러 가지 조항들을 끌고 올 것인지 저는 좀 의문이 듭니다.  지금 말씀하신 부분이 공정거래법 대상이냐 아니냐 부분도 문제가 있습니다. 공정거래법의 대상이 아니라면 공정거래법을 갖다가 몇 조항을, 우월적 지위라는 부분을 갖다가 그렇게 적용할 수 없는 겁니다. 왜냐하면 화주하고 화물운송업자하고 관계를 갖다가 우월적 지위로 본다, 그건 공정거래법상에서 우월적 지위하고 좀 다르거든요. 그것은 협상(bargaining)에 있어 가지고 우월적 지위거든요. 위원님, 물류정책관이 잠깐 말씀드리겠습니다.   사실 위원님 말씀대로 여러 가지 상황이 있는데요 공정거래법상의 위반행위로 판단이 될 경우에는 즉시 공정거래위원회에다가 이첩해서 조사를 하게끔 하고 있습니다. 그렇지만 법률 계약상의 분쟁이 발생해 가지고 이것이 공정거래법을 위반했는지 여부가 불명확하고 다툼이 생길 경우에, 이런 경우에 일차적으로 물류에 전문지식을 갖고 있는 물류업계나 우리 정부에서 한번 분석을 해서 조정해 줄 수 있는 여지가 있다고 볼 수 있을 것이고요.  그다음에는 이런 상황이 발생했을 때 이 모든 것들을 다 공정위에 갖고 가서 해결하기가 굉장히 어렵습니다. 우리 물류업체들은 중소기업이고 아주 작은 업체들이라서 작은 사안들을 가지고 공정거래위 가서 제소하고 이런 경우가 힘들기 때문에 자체적으로 먼저 한 번 걸러주는 시스템이라고 생각하시면 될 것 같습니다. 그동안의 추진 경위를 보니까 이미 국토위 의결안에 대해서 공정위와 이견이 있는 부분이 있었고, 그것을 사실 협의해 가지고 이견을 해소한 거지요? 예, 그렇습니다.  당초에는 공정거래법을 위반한 경우라고 돼 있었는데 이것은 분명하게 공정거래법과 충돌이 되기 때문에 그런 부분들은 제외하고요. 만약에 분쟁이 발생해서 조사를 했는데 공정거래법 위반 사실이 발견되기라도 한다면 바로 이첩을 해서 공정거래위로 하여금 조사토록 하게 되고, 일종의 협업시스템이고요. 저희가 한 번 걸러주고, 실무적으로 한 번 도와주고 이런 시스템이라고 보시면 되겠습니다. 제가 지금 왜 말씀드리냐면 여기 협의회 수정안 37조의3 제1항에 ‘조정을 권고할 수 있다’ 했잖아요? 예, 그렇습니다. 이것도 사실은 이게 공정거래법 대상이 안 되려고 그러면요 공정거래법에 근거가 있어야 됩니다. 이래 놓고 나서, 조정을 권고해 놓고 나서 그렇게 따라서 가면 그 자체가 공정거래법 대상이에요. 그래서 제가 지금 이야기하는 겁니다. 당초에는 시정권고로 돼 있어서 조정으로 바꾼 것이고요.', 'context_summary_summary_q': '국토위 의결안과 공정위의 이견을 협의하고 이견을 해소한 것으로 이해했습니다. 초기에는 공정거래법 위반 사항이 있었으나, 협업시스템을 통해 이를 걸러내고 필요한 경우 공정거래위로 이첩하는 방식으로 문제를 해결했다고 이해했습니다.', 'context_summary_summary_a': ' 네, 정확히 말씀하신 대로입니다. 초기에는 공정거래법 위반 사항을 제외하고 협의를 통해 문제를 해결하는 협업시스템을 운영하고 있습니다. 이렇게 하여 공정위의 이견을 해소하고 원활한 협업을 이끌어내고 있습니다.', 'questioner_name': '박주민', 'questioner_affiliation': '', 'questioner_position': '위원', 'question_comment': '그동안의 추진 경위를 보니까 이미 국토위 의결안에 대해서 공정위와 이견이 있는 부분이 있었고, 그것을 사실 협의해 가지고 이견을 해소한 거지요?', 'question_keyword': '추진, 경위, 국토위, 의결안, 공정위, 부분, 협의', 'answerer_name': '지종철', 'answerer_affiliation': '국토교통부', 'answerer_position': '물류정책관', 'answer_comment': '예, 그렇습니다.  당초에는 공정거래법을 위반한 경우라고 돼 있었는데 이것은 분명하게 공정거래법과 충돌이 되기 때문에 그런 부분들은 제외하고요. 만약에 분쟁이 발생해서 조사를 했는데 공정거래법 위반 사실이 발견되기라도 한다면 바로 이첩을 해서 공정거래위로 하여금 조사토록 하게 되고, 일종의 협업시스템이고요. 저희가 한 번 걸러주고, 실무적으로 한 번 도와주고 이런 시스템이라고 보시면 되겠습니다.', 'answer_keyword': '공정거래법, 위반, 분명, 충돌, 때문, 공정거래위, 조사, 협업시스템, 시스템'}
# --------------------------------------------------

# %%
# Parquet 파일을 cudf로 로드
df = cudf.read_parquet(file_path)

# 결측치(NaN)를 'N/A'로 대체
df = df.fillna('N/A')

# 'content' 열을 벡터화하여 생성
df['content'] = (
    'filename: ' + df['filename'].astype(str) + '\n' +
    'date: ' + df['date'].astype(str) + '\n' +
    'conference_number: ' + df['conference_number'].astype(str) + '\n' +
    'question_number: ' + df['question_number'].astype(str) + '\n' +
    'meeting_name: ' + df['meeting_name'].astype(str) + '\n' +
    'generation_number: ' + df['generation_number'].astype(str) + '\n' +
    'committee_name: ' + df['committee_name'].astype(str) + '\n' +
    'meeting_number: ' + df['meeting_number'].astype(str) + '\n' +
    'session_number: ' + df['session_number'].astype(str) + '\n' +
    'agenda: ' + df['agenda'].astype(str) + '\n' +
    'law: ' + df['law'].astype(str) + '\n' +
    'qna_type: ' + df['qna_type'].astype(str) + '\n' +
    'context: ' + df['context'].astype(str) + '\n' +
    'questioner_name: ' + df['questioner_name'].astype(str) + '\n' +
    'questioner_affiliation: ' + df['questioner_affiliation'].astype(str) + '\n' +
    'questioner_position: ' + df['questioner_position'].astype(str) + '\n' +
    'question_comment: ' + df['question_comment'].astype(str) + '\n' +
    'answerer_name: ' + df['answerer_name'].astype(str) + '\n' +
    'answerer_affiliation: ' + df['answerer_affiliation'].astype(str) + '\n' +
    'answerer_position: ' + df['answerer_position'].astype(str) + '\n' +
    'answer_comment: ' + df['answer_comment'].astype(str) + '\n'
)

# cudf DataFrame을 pandas DataFrame으로 변환
pandas_df = df.to_pandas()

# 데이터 확인
print(pandas_df.head())
# Out:
#                                             filename            date  \
# 0  SRC_16대_2000_2000년10월20일_국정감사_교육위원회_0001(03004...  2000年10月20日(金)
# 1  SRC_16대_2000_2000년10월23일_국정감사_행정자치위원회-제1반_0001...  2000年10月23日(月)
# 2  SRC_16대_2000_2000년10월30일_국정감사_법제사법위원회_0001(028...  2000年10月30日(月)
# 3  SRC_16대_2000_2000년10월31일_국정감사_통일외교통상위원회-아주반_00...  2000年10月31日(火)
# 4  SRC_16대_2000_2000년11월02일_국정감사_재정경제위원회_0001(028...   2000年11月2日(木)
#
#   conference_number question_number meeting_name generation_number  \
# 0            030043            0001         국정감사                16
# 1            028685            0001         국정감사                16
# 2            028928            0001         국정감사                16
# 3            029591            0001         국정감사                16
# 4            028942            0001         국정감사                16
#
#   committee_name meeting_number session_number agenda  ...  \
# 0          교육위원회           2000    2000년10월20일   감사개시  ...
# 1    행정자치위원회-제1반           2000    2000년10월23일   감사개시  ...
# 2        법제사법위원회           2000    2000년10월30일   감사개시  ...
# 3  통일외교통상위원회-아주반           2000    2000년10월31일   감사개시  ...
# 4        재정경제위원회           2000    2000년11월02일   감사개시  ...
#
#   questioner_affiliation questioner_position  \
# 0                                         위원
# 1                                         위원
# 2                                         위원
# 3                                         위원
# 4                                         위원
#
#                                     question_comment  \
# 0  실제로 제가 입수한 자료에 의하면 1997년, 2000년 교육개발원에서 조사한 자료...
# 1  우선 아까 제가 자료요구를 했던 선거구별 단속실적을 좀 다시 보충을 해서 자료로 내...
# 2  그러니까 내가 아까 얘기한 부산지검의 명예를 회복하기 위해서 해야 된다는 얘기이고 ...
# 3  그 샘플을 보여 주십시오.  그다음에 노벨상 수상에 대한 것이라든지 남북정상회담에 ...
# 4  불가사의한 것이 몇 개 있어서 좀 물어보겠습니다.   노사분규를 평화적으로 한 것까...
#
#                              question_keyword answerer_name  \
# 0                           비평준화지역, 평준화지역, 향상           조성윤
# 1            선거구별,  단속실적,  형사입건대상,  선거구별 형사입건           배희선
# 2  부산지검, 검사장, 지역사회, 유착, 다대ㆍ만덕사건, 국정감사, 감사원 감사           송광수
# 3     대상,  샘플,  노벨상,  수상,  남북정상회담,  대통령의,  대북           장세창
# 4                                   노사분규, 인건비           유인학
#
#   answerer_affiliation answerer_position  \
# 0                  경기도               교육감
# 1            전라남도지방경찰청                청장
# 2              부산지방검찰청               검사장
# 3      주중화인민공화국대한민국대사관          공사(문화홍보)
# 4               한국조폐공사                사장
#
#                                       answer_comment  \
# 0  평준화문제는 지금 성남ㆍ분당지역, 고양ㆍ일산지역, 안양지역, 부천지역 그 외에 이삼...
# 1  위원님, 즉답 드리겠습니다.   제가 아까 한번 말씀드렸습니다마는 금년에 오고 나서...
# 2  인사가 된 것이 금년 2월인데 그때는 이영복이가 이미 도주했고 나머지 사람들에 대해...
# 3  중국에서 여론조사 형식을 빌어서 조사하는 것에는 애로가 있습니다.  저희들이 96년...
# 4  정말 위원님께서 염려를 잘 해주셨는데 앞으로 노사관계는 최소한도 형평의 원리가 적용...
#
#                           answer_keyword  \
# 0  교육청, 평준화문제, 성남ㆍ분당지역, 고양ㆍ일산지역, 한국교육개발원
# 1                 전남경찰청,  구조조정,  경찰,  부족
# 2                  승진, 인사, 이영복, 도주, 수사검사
# 3          조사,  중국,  여론조사,  형식,  반응,  언론
# 4                           노사관계, 원리, 적용
#
#                                              content
# 0  filename: SRC_16대_2000_2000년10월20일_국정감사_교육위원회_...
# 1  filename: SRC_16대_2000_2000년10월23일_국정감사_행정자치위원...
# 2  filename: SRC_16대_2000_2000년10월30일_국정감사_법제사법위원...
# 3  filename: SRC_16대_2000_2000년10월31일_국정감사_통일외교통상...
# 4  filename: SRC_16대_2000_2000년11월02일_국정감사_재정경제위원...
#
# [5 rows x 26 columns]

# %%
# Document 객체 생성
documents = [Document(page_content=content, metadata=metadata) for content, metadata in zip(content_list, metadata_list)]

# 일부 Document 객체 출력
for doc in documents[:3]:
    print("Content:\n", doc.page_content)
    print("Metadata:\n", doc.metadata)
    print("-" * 50)
# Out:
# Content:
#  filename: SRC_16대_2000_2000년10월20일_국정감사_교육위원회_0001(030043).xlsx
# date: 2000年10月20日(金)
# conference_number: 030043
# question_number: 0001
# meeting_name: 국정감사
# generation_number: 16
# committee_name: 교육위원회
# meeting_number: 2000
# session_number: 2000년10월20일
# agenda: 감사개시
# law:
# qna_type: 추출형
# context: 任鍾晳 위원입니다.  자료준비와 국정감사를 직접 받으시느라고 많이 피로하실 줄 압니다. 심심한 위로와 감사의 인사를 함께 드립니다.   저는 시간내에 일문일답으로 하겠습니다. 혹시 부족한 것이 있으면 서면으로 하겠습니다.   먼저 인천교육청에 질의 드리겠습니다.   우리가 씨랜드에서도 볼 수 있듯이 학생안전권은 학습권이나 복지권보다 훨씬 중요하다고 생각합니다. 앞서 金貞淑 위원님께서 말씀하셨지만 학생들의 유치원, 초ㆍ중ㆍ고등학교의 통학버스가 종합보험 특별약관에 미가입된 차량들이 전국에 18.2%나 됩니다.   인천도 27.3%가 종합보험 특별약관에 미가입되어서 불의의 사고시 굉장한 피해가 염려되고 있습니다. 서울과 대구, 광주, 경기도는 미가입문제가 깨끗이 정리되어 있고 나머지 지역은 좀 많은 데도 있고 적은 데도 있습니다. 인천은 전국 평균보다 약 10% 높은데 이것을 즉시 해결하는데 어떤 어려움이 있습니까? 말씀드리겠습니다.   인천시내에 초등학교 버스 미가입은 공립의 경우는 없고 사립은 거의 해결됐고 대부분이 유치원입니다. 사립유치원의 버스는 미가입 상태가 많습니다. 고등학교도 꽤 있는데요? 현재 보험에 미가입된 상태는 없습니다. 이것은 제가 자료를 요청해서 받은 것인데 종합보험 특별약관에 인천지역은 중학교만 깨끗할 뿐 초등학교나 고등학교는 미가입 차량들이 있습니다.   공ㆍ사립 불문하고 이것을 즉시 가입시키는 행정조치를 하는데 어려움이 있습니까? 행정조치하는데 그렇게 어렵다는 것은 없는데 하여튼 현재 통계를 받았습니다마는 빠른 시일내에 가입되도록 노력하겠습니다. 이것이 유상운송허가를 받는데 어려움은 있습니다마는 그것은 운송사업법상의 문제이고 일단 이것은 종합보험 특별약관에 1대도 빠짐없이 가입할 수 있도록 즉각 조치해줄 수 있겠지요? 예, 알겠습니다. 이것은 미루지 말고 조치해 주시고 그 조치에 따른 결과를 11월3일까지 본 위원실로 보고해 주시기 바랍니다. 예, 알겠습니다. 그리고 인천에 국제복음학교가 있지요? 예. 2000년3월15일에 국제복음고등학교가 개교했습니다. 그런데 이 복음학교가 개교하면서부터 바로 말썽이 일어났습니다. 복음학교가 설립승인될 때부터 부정과 비리가 지속되어서 학교가 개교하면서 바로 2000년3월 이후에 교실과 교무실에 폐쇄되어서 강당수업을 실시했습니다. 이미 3월30일에 학교운영과 관련해서 시정명령을 교육청에서 내린 적이 있고 5월8일부터 19일까지 특별감사를 실시해서 굉장히 많은 내용에 대한 지시를 내렸습니다.   그리고 제가 7월27일자로 국정감사 자료를 요청하고 9월9일에 임시이사가 파견되었습니다. 그 이후에 여기에 대해서 어떤 정상화 계획을 가지고 계시는지 간단하게 말씀해 주십시오. 현재 관선이사가 파견되어 있고 내년도 학생을 수용하기는 도저히 어려울 것 같아서, 현재 2학급 인가를 신년도 1학급 모집으로 축소시켰습니다. 학교 설립 당시에 40명이었지요? 예. 현재 몇 명입니까? 20명입니다. 수업은 정상적으로 이루어지고 있습니다. 현재 임시이사가 파견되어 있고, 98% 국고보조로 운영되고 있지요? 인건비나 운영비가 전부 보조되고 있습니다. 제가 입수한 자료에 의하면 전체 운영의 98%가 국고보조에 의해서 이루어지고 있는 것으로 알고 있습니다.   현재 교육부 방침은 새로운 독지가가 학교를 인수해 줄 것을 기다리는 것이라고 알고 있는데 그렇습니까? 절충 중에 있으며 새로운 독지가가 나올 것으로 보고 그 독지가가 인수해 줄 것이라는 계획을 가지고 있습니다. 그런 독지가 후보를 알고 계시는 것입니까? 예, 절충 중에 있습니다. 대략 언제쯤이면 알 수 있습니까? 저쪽 답변을 들어봐야 되는데 금년내로 마무리될 것으로 보고 있습니다. 당연히 금년내에 되어야지요. 내년에 학생들을 받아놓고 대책이 없으면 어떻게 됩니까? 그렇다 하더라도 현재 운영비 인건비를 다 대고 있으니까 정상적인 운영을 하고 있습니다. 만약에 독지가가 안 나타날 경우에는 공립화합니까? 마지막에는 그런 방법도 연구해 보겠습니다. 그런데 이 인가를 승인하실 때 이렇게 부실한 상태라는 것이 사전에 전혀 파악이 안 됐습니까? 아니지요. 그전에는 모든 것이 정상적이었는데 인가해놓고 나서부터 상당히 파행적인 운영을 해온 것입니다. 일례로 이사회 회의록까지 위조했다는 문제까지 대두됐습니다. 이것을 빨리 잡지 않으면 안 되겠다는 생각에서 저희가 관선이사를 보내고 정상화노력을 하고 있는 것입니다. 이달 말까지는 새로운 독지가가 학교를 인수할 수 있을지 없을지 대략 결정할 수 있다는 말씀이지요? 예. 이것도 주요 진행상황에 대해서는 본 위원실로 자료를 보내주시기 바랍니다. 알겠습니다. 경기도교육청에 말씀드리겠습니다.  경기도 화성군에 방사성 동위원소 코발트60을 사용해서 식품처리를 하는 주식회사 서야라는 공장이 있는 모양인데 알고 계십니까? 예. 이 회사에서 다루고 있는 방사성 동위원소의 양이 꽤 많은데 이 회사가 인구밀집지역에 있습니다. 더군다나 100m 반경 안에 유치원이 하나 있고, 200m 안에 상신초등학교가 위치하고 있습니다. 그래서 현재 주민대책위가 구성되어서 굉장히 갈등이 많은 상황인데 저희가 이것을 들을 때까지는 경기도교육청과 화성군교육청이 이 사실을 잘 모르고 있는 것 같았습니다.   현재는 정확하게 인지하고 계신가요? 예, 정확하게 파악하고 있습니다. 이 문제는 화성군교육청에서 많은 관심을 가지고 피해가 없도록 조치하고 있다고 저는 그렇게 알고 있습니다. 방사성 동위원소 운반차량이 유치원 바로 앞길로 지나가고 있다고 하는데 그것도 알고 계십니까? 거기까지는 제가 잘 파악하지 못했습니다. 경기도 여주에도 같은 시설이 있는데 이 시설은 반경 1㎞ 안에 아무 것도 없습니다. 인구밀집지역에 더군다나 아이들의 교육시설이 있는 곳에 들어와 있는 것은 이례적인 경우지요? 물론 이것을 교육청이 허가하는 사항은 아닐 것입니다. 그렇지만 주민대책위에서 학생들의 등교거부를 계획하고 있는 것으로 제가 듣고 있습니다. 머지 않아 교육부 문제로 비화될 가능성이 높습니다.   여기에 대해서 앞으로 어떤 조치를 취하시겠는지 즉답이 가능하면 해주시고 안 그러면 답변시간에 해주시기 바랍니다. 제가 아는 범위 내에서 말씀드리겠습니다.  화성 건은 현재 화성군교육청에서 이 공장허가를 취소하였습니다. 그래서 공장가동이 중지된 상태로 있습니다. 그러면 그 공장시설을 완전히 이전할 수 있겠네요? 그래서 화성군청하고 소송관계가 진행되고 있는 것으로 알고 있습니다. 하루라도 빨리 이 문제가 종결될 수 있도록 교육부가 관계기관에 협조를 더 강하게 요청하셔서 지금 현재 주민대책위가 계획하고 있는 학생들의 등교거부같은 사태가 일어나지 않도록 신경을 써주시기 바랍니다. 예, 그렇게 하겠습니다. 경기도지역은 수원과 성남 이외에는 비평준화지역이지요? 그렇습니다. 그런데 최근 교육개발원에서 실시한 여론조사에 의하면 일산ㆍ분당ㆍ안양ㆍ부천 등지에서 학부모들의 70% 이상이 평준화지역으로 전환해 줄 것을 요청한다는 신문보도가 난 적이 있습니다. 보셨습니까? 예, 봤습니다. 실제로 제가 입수한 자료에 의하면 1997년, 2000년 교육개발원에서 조사한 자료에 의하면 비평준화지역에 있는 학교들보다 평준화지역에 있는 학교들의 성적향상률이 높습니다. 상ㆍ중ㆍ하 다 그렇습니다. 성적이 좋았던 아이들이 향상된 정도, 중간이었던 아이들이 향상된 정도, 공부 못했던 아이들이 향상된 정도가 평준화지역이 비평준화지역보다 향상률이 더 높다는 이야기입니다.  그 이야기는 오히려 비평준화지역이 아이들의 교육환경과 교육현실을 왜곡시키는 문제가 더 많이 나타난다는 것입니다. 우수한 아이들만 모아 놓았을 때에도 자살을 한다거나 탈선을 하는 등의 문제가 발생하고, 못하는 아이들은 못하는 아이들대로 포기해버리는 문제들이 평준화지역에 비해서 비평준화지역이 더 심각하다는 이야기입니다.  교육감께서는 이 보도에 의한 것처럼 신도시지역에 대해 신빙성있는 조사를 실시해서 이 보도에 의한 것처럼 70% 이상의 학부모들이 이것을 원한다면 평준화지역으로 전환하실 의사가 있으십니까? 평준화문제는 지금 성남ㆍ분당지역, 고양ㆍ일산지역, 안양지역, 부천지역 그 외에 이삼개 지역해서 7개 지역에서 학부모들이 평준화를 원하고  ...
# questioner_name: 임종석
# questioner_affiliation:
# questioner_position: 위원
# question_comment: 실제로 제가 입수한 자료에 의하면 1997년, 2000년 교육개발원에서 조사한 자료에 의하면 비평준화지역에 있는 학교들보다 평준화지역에 있는 학교들의 성적향상률이 높습니다. 상ㆍ중ㆍ하 다 그렇습니다. 성적이 좋았던 아이들이 향상된 정도, 중간이었던 아이들이 향상된 정도, 공부 못했던 아이들이 향상된 정도가 평준화지역이 비평준화지역보다 향상률이 더 높다는 이야기입니다.  그 이야기는 오히려 비평준화지역이 아이들의 교육환경과 교육현실을 왜곡시키는 문제가 더 많이 나타난다는 것입니다. 우수한 아이들만 모아 놓았을 때에도 자살을 한다거나 탈선을 하는 등의 문제가 발생하고, 못하는 아이들은 못하는 아이들대로 포기해버리는 문제들이 평준화지역에 비해서 비평준화지역이 더 심각하다는 이야기입니다.  교육감께서는 이 보도에 의한 것처럼 신도시지역에 대해 신빙성있는 조사를 실시해서 이 보도에 의한 것처럼 70% 이상의 학부모들이 이것을 원한다면 평준화지역으로 전환하실 의사가 있으십니까?
# answerer_name: 조성윤
# answerer_affiliation: 경기도
# answerer_position: 교육감
# answer_comment: 평준화문제는 지금 성남ㆍ분당지역, 고양ㆍ일산지역, 안양지역, 부천지역 그 외에 이삼개 지역해서 7개 지역에서 학부모들이 평준화를 원하고 계시는데 반대하는 학부모도 많이 있습니다.   그래서 이것은 우리 교육청 단독으로 정책을 결정하기가 너무나 어려운 일이기 때문에 금년 초에 한국교육개발원에 용역을 주어서, 오늘 이 시간에도 안양지역에서 공청회가 이루어지고 있는 것으로 알고 있습니다. 11월 말에 보고자료가 저희에게 오면 면밀히 검토해서 내년 초에 정책을 결정하려고 생각하고 있습니다.
#
# Metadata:
#  {'filename': 'SRC_16대_2000_2000년10월20일_국정감사_교육위원회_0001(030043).xlsx', 'date': '2000年10月20日(金)', 'conference_number': '030043', 'question_number': '0001', 'meeting_name': '국정감사', 'generation_number': '16', 'committee_name': '교육위원회', 'meeting_number': '2000', 'session_number': '2000년10월20일', 'agenda': '감사개시', 'law': '', 'qna_type': '추출형', 'context': '任鍾晳 위원입니다.  자료준비와 국정감사를 직접 받으시느라고 많이 피로하실 줄 압니다. 심심한 위로와 감사의 인사를 함께 드립니다.   저는 시간내에 일문일답으로 하겠습니다. 혹시 부족한 것이 있으면 서면으로 하겠습니다.   먼저 인천교육청에 질의 드리겠습니다.   우리가 씨랜드에서도 볼 수 있듯이 학생안전권은 학습권이나 복지권보다 훨씬 중요하다고 생각합니다. 앞서 金貞淑 위원님께서 말씀하셨지만 학생들의 유치원, 초ㆍ중ㆍ고등학교의 통학버스가 종합보험 특별약관에 미가입된 차량들이 전국에 18.2%나 됩니다.   인천도 27.3%가 종합보험 특별약관에 미가입되어서 불의의 사고시 굉장한 피해가 염려되고 있습니다. 서울과 대구, 광주, 경기도는 미가입문제가 깨끗이 정리되어 있고 나머지 지역은 좀 많은 데도 있고 적은 데도 있습니다. 인천은 전국 평균보다 약 10% 높은데 이것을 즉시 해결하는데 어떤 어려움이 있습니까? 말씀드리겠습니다.   인천시내에 초등학교 버스 미가입은 공립의 경우는 없고 사립은 거의 해결됐고 대부분이 유치원입니다. 사립유치원의 버스는 미가입 상태가 많습니다. 고등학교도 꽤 있는데요? 현재 보험에 미가입된 상태는 없습니다. 이것은 제가 자료를 요청해서 받은 것인데 종합보험 특별약관에 인천지역은 중학교만 깨끗할 뿐 초등학교나 고등학교는 미가입 차량들이 있습니다.   공ㆍ사립 불문하고 이것을 즉시 가입시키는 행정조치를 하는데 어려움이 있습니까? 행정조치하는데 그렇게 어렵다는 것은 없는데 하여튼 현재 통계를 받았습니다마는 빠른 시일내에 가입되도록 노력하겠습니다. 이것이 유상운송허가를 받는데 어려움은 있습니다마는 그것은 운송사업법상의 문제이고 일단 이것은 종합보험 특별약관에 1대도 빠짐없이 가입할 수 있도록 즉각 조치해줄 수 있겠지요? 예, 알겠습니다. 이것은 미루지 말고 조치해 주시고 그 조치에 따른 결과를 11월3일까지 본 위원실로 보고해 주시기 바랍니다. 예, 알겠습니다. 그리고 인천에 국제복음학교가 있지요? 예. 2000년3월15일에 국제복음고등학교가 개교했습니다. 그런데 이 복음학교가 개교하면서부터 바로 말썽이 일어났습니다. 복음학교가 설립승인될 때부터 부정과 비리가 지속되어서 학교가 개교하면서 바로 2000년3월 이후에 교실과 교무실에 폐쇄되어서 강당수업을 실시했습니다. 이미 3월30일에 학교운영과 관련해서 시정명령을 교육청에서 내린 적이 있고 5월8일부터 19일까지 특별감사를 실시해서 굉장히 많은 내용에 대한 지시를 내렸습니다.   그리고 제가 7월27일자로 국정감사 자료를 요청하고 9월9일에 임시이사가 파견되었습니다. 그 이후에 여기에 대해서 어떤 정상화 계획을 가지고 계시는지 간단하게 말씀해 주십시오. 현재 관선이사가 파견되어 있고 내년도 학생을 수용하기는 도저히 어려울 것 같아서, 현재 2학급 인가를 신년도 1학급 모집으로 축소시켰습니다. 학교 설립 당시에 40명이었지요? 예. 현재 몇 명입니까? 20명입니다. 수업은 정상적으로 이루어지고 있습니다. 현재 임시이사가 파견되어 있고, 98% 국고보조로 운영되고 있지요? 인건비나 운영비가 전부 보조되고 있습니다. 제가 입수한 자료에 의하면 전체 운영의 98%가 국고보조에 의해서 이루어지고 있는 것으로 알고 있습니다.   현재 교육부 방침은 새로운 독지가가 학교를 인수해 줄 것을 기다리는 것이라고 알고 있는데 그렇습니까? 절충 중에 있으며 새로운 독지가가 나올 것으로 보고 그 독지가가 인수해 줄 것이라는 계획을 가지고 있습니다. 그런 독지가 후보를 알고 계시는 것입니까? 예, 절충 중에 있습니다. 대략 언제쯤이면 알 수 있습니까? 저쪽 답변을 들어봐야 되는데 금년내로 마무리될 것으로 보고 있습니다. 당연히 금년내에 되어야지요. 내년에 학생들을 받아놓고 대책이 없으면 어떻게 됩니까? 그렇다 하더라도 현재 운영비 인건비를 다 대고 있으니까 정상적인 운영을 하고 있습니다. 만약에 독지가가 안 나타날 경우에는 공립화합니까? 마지막에는 그런 방법도 연구해 보겠습니다. 그런데 이 인가를 승인하실 때 이렇게 부실한 상태라는 것이 사전에 전혀 파악이 안 됐습니까? 아니지요. 그전에는 모든 것이 정상적이었는데 인가해놓고 나서부터 상당히 파행적인 운영을 해온 것입니다. 일례로 이사회 회의록까지 위조했다는 문제까지 대두됐습니다. 이것을 빨리 잡지 않으면 안 되겠다는 생각에서 저희가 관선이사를 보내고 정상화노력을 하고 있는 것입니다. 이달 말까지는 새로운 독지가가 학교를 인수할 수 있을지 없을지 대략 결정할 수 있다는 말씀이지요? 예. 이것도 주요 진행상황에 대해서는 본 위원실로 자료를 보내주시기 바랍니다. 알겠습니다. 경기도교육청에 말씀드리겠습니다.  경기도 화성군에 방사성 동위원소 코발트60을 사용해서 식품처리를 하는 주식회사 서야라는 공장이 있는 모양인데 알고 계십니까? 예. 이 회사에서 다루고 있는 방사성 동위원소의 양이 꽤 많은데 이 회사가 인구밀집지역에 있습니다. 더군다나 100m 반경 안에 유치원이 하나 있고, 200m 안에 상신초등학교가 위치하고 있습니다. 그래서 현재 주민대책위가 구성되어서 굉장히 갈등이 많은 상황인데 저희가 이것을 들을 때까지는 경기도교육청과 화성군교육청이 이 사실을 잘 모르고 있는 것 같았습니다.   현재는 정확하게 인지하고 계신가요? 예, 정확하게 파악하고 있습니다. 이 문제는 화성군교육청에서 많은 관심을 가지고 피해가 없도록 조치하고 있다고 저는 그렇게 알고 있습니다. 방사성 동위원소 운반차량이 유치원 바로 앞길로 지나가고 있다고 하는데 그것도 알고 계십니까? 거기까지는 제가 잘 파악하지 못했습니다. 경기도 여주에도 같은 시설이 있는데 이 시설은 반경 1㎞ 안에 아무 것도 없습니다. 인구밀집지역에 더군다나 아이들의 교육시설이 있는 곳에 들어와 있는 것은 이례적인 경우지요? 물론 이것을 교육청이 허가하는 사항은 아닐 것입니다. 그렇지만 주민대책위에서 학생들의 등교거부를 계획하고 있는 것으로 제가 듣고 있습니다. 머지 않아 교육부 문제로 비화될 가능성이 높습니다.   여기에 대해서 앞으로 어떤 조치를 취하시겠는지 즉답이 가능하면 해주시고 안 그러면 답변시간에 해주시기 바랍니다. 제가 아는 범위 내에서 말씀드리겠습니다.  화성 건은 현재 화성군교육청에서 이 공장허가를 취소하였습니다. 그래서 공장가동이 중지된 상태로 있습니다. 그러면 그 공장시설을 완전히 이전할 수 있겠네요? 그래서 화성군청하고 소송관계가 진행되고 있는 것으로 알고 있습니다. 하루라도 빨리 이 문제가 종결될 수 있도록 교육부가 관계기관에 협조를 더 강하게 요청하셔서 지금 현재 주민대책위가 계획하고 있는 학생들의 등교거부같은 사태가 일어나지 않도록 신경을 써주시기 바랍니다. 예, 그렇게 하겠습니다. 경기도지역은 수원과 성남 이외에는 비평준화지역이지요? 그렇습니다. 그런데 최근 교육개발원에서 실시한 여론조사에 의하면 일산ㆍ분당ㆍ안양ㆍ부천 등지에서 학부모들의 70% 이상이 평준화지역으로 전환해 줄 것을 요청한다는 신문보도가 난 적이 있습니다. 보셨습니까? 예, 봤습니다. 실제로 제가 입수한 자료에 의하면 1997년, 2000년 교육개발원에서 조사한 자료에 의하면 비평준화지역에 있는 학교들보다 평준화지역에 있는 학교들의 성적향상률이 높습니다. 상ㆍ중ㆍ하 다 그렇습니다. 성적이 좋았던 아이들이 향상된 정도, 중간이었던 아이들이 향상된 정도, 공부 못했던 아이들이 향상된 정도가 평준화지역이 비평준화지역보다 향상률이 더 높다는 이야기입니다.  그 이야기는 오히려 비평준화지역 ...
# --------------------------------------------------
# Content:
#  filename: SRC_16대_2000_2000년10월23일_국정감사_행정자치위원회-제1반_0001(028685).xlsx
# date: 2000年10月23日(月)
# conference_number: 028685
# question_number: 0001
# meeting_name: 국정감사
# generation_number: 16
# committee_name: 행정자치위원회-제1반
# meeting_number: 2000
# session_number: 2000년10월23일
# agenda: 감사개시
# law:
# qna_type: 추출형
# context: 우선 아까 제가 자료요구를 했던 선거구별 단속실적을 좀 다시 보충을 해서 자료로 내주십시오. 선거구별 단속실적을 기초로 해서 각 선거구별 형사입건대상을 당별로 분류를 해주시기 바랍니다. 이것은 가능하면 전남도청 국감 끝나기 전까지 제출해 주시기 바라고요.  한 가지 의문사항이 하나 있는데 경찰관들 정ㆍ현원을 보니까 지방청의 경우는 416명이 정원인데 과부족이 플러스 28명, 28명이 남는다는 얘기인데 경찰서 보니까 6,402명 정원에 현원이 6,766명에서 364명이 남습니다. 왜 이렇게 남지요? 위원님, 즉답 드리겠습니다.   제가 아까 한번 말씀드렸습니다마는 금년에 오고 나서 전남경찰청 정원이 468명이 줄었습니다. 이유는 전국적으로 구조조정 차원에서 경기도 수도권의 경찰이 부족하기 때문에 우리 전남경찰청에서 많이 줄여 가지고 그렇게 올려졌습니다. 그 바람에 지금 현재 사람은 있는데 T/O가 많이 줄었습니다. 그래서 경찰청에도 승진을 해서 나가거나 발령을 받아서 나가면 받지 않는 것으로 그렇게 하고 있습니다. 현재 있는 468명을 어디로 다 내보낼 수 없기 때문에 그렇습니다. 지금 수도권에는 경찰력이 부족해서 난리인데요. T/O가 줄었기 때문에 지금 현재 과원이 되었지요. 그러면 이 분들이 보직이 없다는 말입니까? 근무는 현재 그대로 하고 있습니다마는 T/O가 468명이 줄어버렸습니다. 사람은 여기 있는데 그래서······. 그래서 경사직을 보면 1,545명이나 남아요. 그것도 구조조정문제가 위에서 검토되겠습니다마는 자연적으로 승진이 되기 때문에 그런 것입니다. 순경은 1,078명이 부족하고 경사는 1,545명이 남고······. 자동승진제도가 있기 때문에 그렇습니다. 자동승진제도도 그렇지요. 순경이 할 일이 있고 경사가 할 일이 있는데 총 정원이 7,054명인데 이것 너무 심한 불균형 아닙니까? 외람된 말씀입니다마는 전국적인 현상일 것입니다. 그래서 그것을 검토하셔 가지고 지적하시면 저희들이 가능한 한······. 다른 방법은 없을 것입니다. 처음이라 의문이 생기는데 말이지요. 수도권에는 남는 인력이 거의 없습니다. 그런데 경사가 1,545명이 남는다고 하면 예를 들어서 파출소 같은 경우 보자 이거예요. 궂은 일은 순경들이 하고 경사들은 순회근무하고 이렇게 되는데 이렇게 경사는 1,545명이 남고 순경은 1,078명이 부족하고 그러면 치안운영에 굉장히 문제가 있는 것이 아니냐, 개선안이라든가 건의안 낸 것 있습니까? 위의 경찰청 단위에서 다 검토가 되고 있는 것으로 알고 있습니다. 지방청 단위에서 그런 부분에 대해서 어떤 어려움이 있습니까? 어려움이 있다면 경사에서 경위로 자꾸 승진시켜 준다든가 그렇게 하는 것 아니고는, 왜냐 하면······. 경위도 51명이 남아요. 승진시켜 주면 경위가 또 남는 것 아닙니까? 이번에 정원에 오버되는 것은 현원은 아직 그대로 있는데 정원이 7,500명에서 468명이 정원이 줄었습니다. 줄었기 때문에 정원보다 현원이 많다는 얘기이지요. 금년에 들어와 가지고 정원이 줄어들었기 때문에 사람이 남는 것으로 되어 있습니다. 실제로······. 보면 정원이 7,054명인데 현원은 7,470명이에요. 과부족이 플러스 416명이라는 말이지요. 416명이 남는데 남는 것은 어쩔 수 없다치고 경사가 1,545명이 남고 순경은 1,078명이 부족하고 지휘관으로 어떤 입장에 있습니까? 위원님, 그 이유는 순경에서 6년 있으면 자동으로 경장이 되고······. 순경이 부족한 것은 순경채용을 덜하게 된 것이지요? 순경채용을 줄인 것 아닙니까? 덜해서 그런 것이 아니고요, 우리 경찰인력이 전국의 경찰이 9만 몇백 명이 됩니다. 순경을 많이 모집하지 못 해서 그런 것은 아닙니다. 순경은 없고 경장이 많은 것은 자동적으로 몇 년 되면 순경에서 경장이 되고, 경장에서 몇 년이 되면 경사가 자동적으로 됩니다. 그 바람에 경장하고 경사가 많아지는데 순경은······. 이해가 좀 안 되는데 하여튼 차후에 그런 문제점에 대해서 건의안을 하나 마련해서 본 위원에게 제출해 주시기 바랍니다.  이상입니다.
# questioner_name: 박종희
# questioner_affiliation:
# questioner_position: 위원
# question_comment: 우선 아까 제가 자료요구를 했던 선거구별 단속실적을 좀 다시 보충을 해서 자료로 내주십시오. 선거구별 단속실적을 기초로 해서 각 선거구별 형사입건대상을 당별로 분류를 해주시기 바랍니다. 이것은 가능하면 전남도청 국감 끝나기 전까지 제출해 주시기 바라고요.  한 가지 의문사항이 하나 있는데 경찰관들 정ㆍ현원을 보니까 지방청의 경우는 416명이 정원인데 과부족이 플러스 28명, 28명이 남는다는 얘기인데 경찰서 보니까 6,402명 정원에 현원이 6,766명에서 364명이 남습니다. 왜 이렇게 남지요?
# answerer_name: 배희선
# answerer_affiliation: 전라남도지방경찰청
# answerer_position: 청장
# answer_comment: 위원님, 즉답 드리겠습니다.   제가 아까 한번 말씀드렸습니다마는 금년에 오고 나서 전남경찰청 정원이 468명이 줄었습니다. 이유는 전국적으로 구조조정 차원에서 경기도 수도권의 경찰이 부족하기 때문에 우리 전남경찰청에서 많이 줄여 가지고 그렇게 올려졌습니다. 그 바람에 지금 현재 사람은 있는데 T/O가 많이 줄었습니다. 그래서 경찰청에도 승진을 해서 나가거나 발령을 받아서 나가면 받지 않는 것으로 그렇게 하고 있습니다. 현재 있는 468명을 어디로 다 내보낼 수 없기 때문에 그렇습니다.
#
# Metadata:
#  {'filename': 'SRC_16대_2000_2000년10월23일_국정감사_행정자치위원회-제1반_0001(028685).xlsx', 'date': '2000年10月23日(月)', 'conference_number': '028685', 'question_number': '0001', 'meeting_name': '국정감사', 'generation_number': '16', 'committee_name': '행정자치위원회-제1반', 'meeting_number': '2000', 'session_number': '2000년10월23일', 'agenda': '감사개시', 'law': '', 'qna_type': '추출형', 'context': '우선 아까 제가 자료요구를 했던 선거구별 단속실적을 좀 다시 보충을 해서 자료로 내주십시오. 선거구별 단속실적을 기초로 해서 각 선거구별 형사입건대상을 당별로 분류를 해주시기 바랍니다. 이것은 가능하면 전남도청 국감 끝나기 전까지 제출해 주시기 바라고요.  한 가지 의문사항이 하나 있는데 경찰관들 정ㆍ현원을 보니까 지방청의 경우는 416명이 정원인데 과부족이 플러스 28명, 28명이 남는다는 얘기인데 경찰서 보니까 6,402명 정원에 현원이 6,766명에서 364명이 남습니다. 왜 이렇게 남지요? 위원님, 즉답 드리겠습니다.   제가 아까 한번 말씀드렸습니다마는 금년에 오고 나서 전남경찰청 정원이 468명이 줄었습니다. 이유는 전국적으로 구조조정 차원에서 경기도 수도권의 경찰이 부족하기 때문에 우리 전남경찰청에서 많이 줄여 가지고 그렇게 올려졌습니다. 그 바람에 지금 현재 사람은 있는데 T/O가 많이 줄었습니다. 그래서 경찰청에도 승진을 해서 나가거나 발령을 받아서 나가면 받지 않는 것으로 그렇게 하고 있습니다. 현재 있는 468명을 어디로 다 내보낼 수 없기 때문에 그렇습니다. 지금 수도권에는 경찰력이 부족해서 난리인데요. T/O가 줄었기 때문에 지금 현재 과원이 되었지요. 그러면 이 분들이 보직이 없다는 말입니까? 근무는 현재 그대로 하고 있습니다마는 T/O가 468명이 줄어버렸습니다. 사람은 여기 있는데 그래서······. 그래서 경사직을 보면 1,545명이나 남아요. 그것도 구조조정문제가 위에서 검토되겠습니다마는 자연적으로 승진이 되기 때문에 그런 것입니다. 순경은 1,078명이 부족하고 경사는 1,545명이 남고······. 자동승진제도가 있기 때문에 그렇습니다. 자동승진제도도 그렇지요. 순경이 할 일이 있고 경사가 할 일이 있는데 총 정원이 7,054명인데 이것 너무 심한 불균형 아닙니까? 외람된 말씀입니다마는 전국적인 현상일 것입니다. 그래서 그것을 검토하셔 가지고 지적하시면 저희들이 가능한 한······. 다른 방법은 없을 것입니다. 처음이라 의문이 생기는데 말이지요. 수도권에는 남는 인력이 거의 없습니다. 그런데 경사가 1,545명이 남는다고 하면 예를 들어서 파출소 같은 경우 보자 이거예요. 궂은 일은 순경들이 하고 경사들은 순회근무하고 이렇게 되는데 이렇게 경사는 1,545명이 남고 순경은 1,078명이 부족하고 그러면 치안운영에 굉장히 문제가 있는 것이 아니냐, 개선안이라든가 건의안 낸 것 있습니까? 위의 경찰청 단위에서 다 검토가 되고 있는 것으로 알고 있습니다. 지방청 단위에서 그런 부분에 대해서 어떤 어려움이 있습니까? 어려움이 있다면 경사에서 경위로 자꾸 승진시켜 준다든가 그렇게 하는 것 아니고는, 왜냐 하면······. 경위도 51명이 남아요. 승진시켜 주면 경위가 또 남는 것 아닙니까? 이번에 정원에 오버되는 것은 현원은 아직 그대로 있는데 정원이 7,500명에서 468명이 정원이 줄었습니다. 줄었기 때문에 정원보다 현원이 많다는 얘기이지요. 금년에 들어와 가지고 정원이 줄어들었기 때문에 사람이 남는 것으로 되어 있습니다. 실제로······. 보면 정원이 7,054명인데 현원은 7,470명이에요. 과부족이 플러스 416명이라는 말이지요. 416명이 남는데 남는 것은 어쩔 수 없다치고 경사가 1,545명이 남고 순경은 1,078명이 부족하고 지휘관으로 어떤 입장에 있습니까? 위원님, 그 이유는 순경에서 6년 있으면 자동으로 경장이 되고······. 순경이 부족한 것은 순경채용을 덜하게 된 것이지요? 순경채용을 줄인 것 아닙니까? 덜해서 그런 것이 아니고요, 우리 경찰인력이 전국의 경찰이 9만 몇백 명이 됩니다. 순경을 많이 모집하지 못 해서 그런 것은 아닙니다. 순경은 없고 경장이 많은 것은 자동적으로 몇 년 되면 순경에서 경장이 되고, 경장에서 몇 년이 되면 경사가 자동적으로 됩니다. 그 바람에 경장하고 경사가 많아지는데 순경은······. 이해가 좀 안 되는데 하여튼 차후에 그런 문제점에 대해서 건의안을 하나 마련해서 본 위원에게 제출해 주시기 바랍니다.  이상입니다.', 'context_summary_summary_q': '선거구별 단속실적과 선거구별 형사입건대상 분류에 대한 자료를 요청하였습니다. 이 자료를 전남도청 국감이 끝나기 전까지 제출 가능한지 확인하고, 또 경찰청과 지방 경찰청의 정원과 현원 차이에 대한 이유를 설명해주십시오.', 'context_summary_summary_a': '전남경찰청의 정원이 줄어들고 경찰청 및 지방 경찰청의 현원이 증가한 이유는 경찰 구조 조정과 부족한 지역의 경찰 증원으로 인한 것입니다. 현원과 정원의 차이로 인해 발령 및 승진으로 조정 작업을 진행하고 있으며, 현황에 대한 자세한 정보를 제공하겠습니다. 또한 선거구별 단속실적과 형사입건대상 분류에 관한 자료 역시 요청하신 기한 내에 제출할 수 있을 것입니다.', 'questioner_name': '박종희', 'questioner_affiliation': '', 'questioner_position': '위원', 'question_comment': '우선 아까 제가 자료요구를 했던 선거구별 단속실적을 좀 다시 보충을 해서 자료로 내주십시오. 선거구별 단속실적을 기초로 해서 각 선거구별 형사입건대상을 당별로 분류를 해주시기 바랍니다. 이것은 가능하면 전남도청 국감 끝나기 전까지 제출해 주시기 바라고요.  한 가지 의문사항이 하나 있는데 경찰관들 정ㆍ현원을 보니까 지방청의 경우는 416명이 정원인데 과부족이 플러스 28명, 28명이 남는다는 얘기인데 경찰서 보니까 6,402명 정원에 현원이 6,766명에서 364명이 남습니다. 왜 이렇게 남지요?', 'question_keyword': '선거구별,  단속실적,  형사입건대상,  선거구별 형사입건', 'answerer_name': '배희선', 'answerer_affiliation': '전라남도지방경찰청', 'answerer_position': '청장', 'answer_comment': '위원님, 즉답 드리겠습니다.   제가 아까 한번 말씀드렸습니다마는 금년에 오고 나서 전남경찰청 정원이 468명이 줄었습니다. 이유는 전국적으로 구조조정 차원에서 경기도 수도권의 경찰이 부족하기 때문에 우리 전남경찰청에서 많이 줄여 가지고 그렇게 올려졌습니다. 그 바람에 지금 현재 사람은 있는데 T/O가 많이 줄었습니다. 그래서 경찰청에도 승진을 해서 나가거나 발령을 받아서 나가면 받지 않는 것으로 그렇게 하고 있습니다. 현재 있는 468명을 어디로 다 내보낼 수 없기 때문에 그렇습니다.', 'answer_keyword': '전남경찰청,  구조조정,  경찰,  부족'}
# --------------------------------------------------
# Content:
#  filename: SRC_16대_2000_2000년10월30일_국정감사_법제사법위원회_0001(028928).xlsx
# date: 2000年10月30日(月)
# conference_number: 028928
# question_number: 0001
# meeting_name: 국정감사
# generation_number: 16
# committee_name: 법제사법위원회
# meeting_number: 2000
# session_number: 2000년10월30일
# agenda: 감사개시
# law:
# qna_type: 추출형
# context: 한 가지만 여쭈어 보겠습니다.  먼저 전임 지검 검사장 두 분이 다대ㆍ만덕사건으로 구속기소된 피고인의 변호인으로 선임되어 있다는데 그것이 사실입니까? 예, 그렇게 알고 있습니다. 저는 이 얘기를 듣고 물론 법적으로는 모르겠습니다마는 두 전임 검사장 중의 한 분은 2년 전 바로 이 국정감사장에서, 그 당시 감사원 감사가 착수될 시기였습니다. 그래서 감사원 감사가 끝나면 수사에 착수할 용의가 있는가, 철저한 수사촉구를 저뿐만 아니고 다른 여야위원들이 했습니다. 그때 분명히 여기서 감사원 감사가 끝나면 철저한 수사에 착수하겠다고 답변했습니다.  그런데 그 본인이 재직하던 지검에서, 수사ㆍ지휘하던 사건에 어떻게 변호인으로 선임됩니까? 이것은 정말 도덕적으로 윤리적으로 어떻게 이럴 수가 있습니까? 뒤에 후배검사들 여러분들 있는데 그 후배검사들을 봐서도 수사를 담당했던…… 어떻게 그렇게 할 수 있는지, 그래 가지고 구속기소된 주택조합의 두 사람이 이번에 보석이 되었다고 하는데 맞지요? 지난번에 보석되었습니다. 그러면 일반 국민의 입장에서 과연 이것이 정상적인 변론ㆍ변호활동에 의해서 이렇게 되었다고 보겠습니까? 그리고 한 사람의 변호인은 전 부산고법원장이 선임되어 있데요, 어떻게 직접 수사지휘를 했던 검사장인데 그럴 수가 있습니까? 그분들하고 얘기해 보신 적 없으세요? 다대ㆍ만덕사건의 주범이라기보다는 신용금고의 관련자를 선임한 것을 알고 있습니다마는 위원님께서 지적하신 문제점이 있습니다. 그래서 본인한테 위원님의 걱정을 정확히 전달하도록 하겠습니다. 그러니까 내가 아까 얘기한 부산지검의 명예를 회복하기 위해서 해야 된다는 얘기이고 그 이전의 지검 검사장도 이 지역사회에서 유착되었다는 설도 여기에서는 널리 유포되어 있었습니다. 그런데다가 최근에 두 지검 검사장이 이 사건의 변호인으로 선임되고 하니까 점점 부산지검은 다대ㆍ만덕사건에 관한 한 처음부터 수사를 못 하게 되어 있는 사건이다, 내가 아까 말한 대로 국정감사 때마다 요구하고 추궁하고 또 감사원 감사가 착수되고 하니까 할 수 없이 등 떠밀려서 마지못해서 하는 것 아니냐 하는 것입니다.  수사진은 왜 교체했습니까? 인사가 된 것이 금년 2월인데 그때는 이영복이가 이미 도주했고 나머지 사람들에 대해서는 1월 중에 다 기소된 뒤였습니다. 그렇기 때문에 정기인사에 따라서 부장검사가 서울로 갈 차례이고 또 수사검사는 부부장으로 승진을 하게 되어 있었습니다.  저희들 관행에 따르면 부부장검사로 승진을 하면 다른 청에 가게 되어 있습니다. 그렇게 해서 가기는 했습니다마는 후임 부장이나 후임 검사들의 수사열의는 또 수사에 대한 파악도는 전임자들에 결코 못지않다는 것을 말씀드립니다. 그러나 그것도 이 지역사회나 시민단체 등등에서는 크게 오해하고 문제를 삼았고 지금도 그런 것 아닙니까? 그렇습니다. 그러니까 내가 당부드리는데 내년에 또 국정감사 와서 얘기하지 않도록 부산지검의 명예와 전체 검찰의 명예를 걸고 이 사건을 공개하세요.
# questioner_name: 조순형
# questioner_affiliation:
# questioner_position: 위원
# question_comment: 그러니까 내가 아까 얘기한 부산지검의 명예를 회복하기 위해서 해야 된다는 얘기이고 그 이전의 지검 검사장도 이 지역사회에서 유착되었다는 설도 여기에서는 널리 유포되어 있었습니다. 그런데다가 최근에 두 지검 검사장이 이 사건의 변호인으로 선임되고 하니까 점점 부산지검은 다대ㆍ만덕사건에 관한 한 처음부터 수사를 못 하게 되어 있는 사건이다, 내가 아까 말한 대로 국정감사 때마다 요구하고 추궁하고 또 감사원 감사가 착수되고 하니까 할 수 없이 등 떠밀려서 마지못해서 하는 것 아니냐 하는 것입니다.  수사진은 왜 교체했습니까?
# answerer_name: 송광수
# answerer_affiliation: 부산지방검찰청
# answerer_position: 검사장
# answer_comment: 인사가 된 것이 금년 2월인데 그때는 이영복이가 이미 도주했고 나머지 사람들에 대해서는 1월 중에 다 기소된 뒤였습니다. 그렇기 때문에 정기인사에 따라서 부장검사가 서울로 갈 차례이고 또 수사검사는 부부장으로 승진을 하게 되어 있었습니다.  저희들 관행에 따르면 부부장검사로 승진을 하면 다른 청에 가게 되어 있습니다. 그렇게 해서 가기는 했습니다마는 후임 부장이나 후임 검사들의 수사열의는 또 수사에 대한 파악도는 전임자들에 결코 못지않다는 것을 말씀드립니다.
#
# Metadata:
#  {'filename': 'SRC_16대_2000_2000년10월30일_국정감사_법제사법위원회_0001(028928).xlsx', 'date': '2000年10月30日(月)', 'conference_number': '028928', 'question_number': '0001', 'meeting_name': '국정감사', 'generation_number': '16', 'committee_name': '법제사법위원회', 'meeting_number': '2000', 'session_number': '2000년10월30일', 'agenda': '감사개시', 'law': '', 'qna_type': '추출형', 'context': '한 가지만 여쭈어 보겠습니다.  먼저 전임 지검 검사장 두 분이 다대ㆍ만덕사건으로 구속기소된 피고인의 변호인으로 선임되어 있다는데 그것이 사실입니까? 예, 그렇게 알고 있습니다. 저는 이 얘기를 듣고 물론 법적으로는 모르겠습니다마는 두 전임 검사장 중의 한 분은 2년 전 바로 이 국정감사장에서, 그 당시 감사원 감사가 착수될 시기였습니다. 그래서 감사원 감사가 끝나면 수사에 착수할 용의가 있는가, 철저한 수사촉구를 저뿐만 아니고 다른 여야위원들이 했습니다. 그때 분명히 여기서 감사원 감사가 끝나면 철저한 수사에 착수하겠다고 답변했습니다.  그런데 그 본인이 재직하던 지검에서, 수사ㆍ지휘하던 사건에 어떻게 변호인으로 선임됩니까? 이것은 정말 도덕적으로 윤리적으로 어떻게 이럴 수가 있습니까? 뒤에 후배검사들 여러분들 있는데 그 후배검사들을 봐서도 수사를 담당했던…… 어떻게 그렇게 할 수 있는지, 그래 가지고 구속기소된 주택조합의 두 사람이 이번에 보석이 되었다고 하는데 맞지요? 지난번에 보석되었습니다. 그러면 일반 국민의 입장에서 과연 이것이 정상적인 변론ㆍ변호활동에 의해서 이렇게 되었다고 보겠습니까? 그리고 한 사람의 변호인은 전 부산고법원장이 선임되어 있데요, 어떻게 직접 수사지휘를 했던 검사장인데 그럴 수가 있습니까? 그분들하고 얘기해 보신 적 없으세요? 다대ㆍ만덕사건의 주범이라기보다는 신용금고의 관련자를 선임한 것을 알고 있습니다마는 위원님께서 지적하신 문제점이 있습니다. 그래서 본인한테 위원님의 걱정을 정확히 전달하도록 하겠습니다. 그러니까 내가 아까 얘기한 부산지검의 명예를 회복하기 위해서 해야 된다는 얘기이고 그 이전의 지검 검사장도 이 지역사회에서 유착되었다는 설도 여기에서는 널리 유포되어 있었습니다. 그런데다가 최근에 두 지검 검사장이 이 사건의 변호인으로 선임되고 하니까 점점 부산지검은 다대ㆍ만덕사건에 관한 한 처음부터 수사를 못 하게 되어 있는 사건이다, 내가 아까 말한 대로 국정감사 때마다 요구하고 추궁하고 또 감사원 감사가 착수되고 하니까 할 수 없이 등 떠밀려서 마지못해서 하는 것 아니냐 하는 것입니다.  수사진은 왜 교체했습니까? 인사가 된 것이 금년 2월인데 그때는 이영복이가 이미 도주했고 나머지 사람들에 대해서는 1월 중에 다 기소된 뒤였습니다. 그렇기 때문에 정기인사에 따라서 부장검사가 서울로 갈 차례이고 또 수사검사는 부부장으로 승진을 하게 되어 있었습니다.  저희들 관행에 따르면 부부장검사로 승진을 하면 다른 청에 가게 되어 있습니다. 그렇게 해서 가기는 했습니다마는 후임 부장이나 후임 검사들의 수사열의는 또 수사에 대한 파악도는 전임자들에 결코 못지않다는 것을 말씀드립니다. 그러나 그것도 이 지역사회나 시민단체 등등에서는 크게 오해하고 문제를 삼았고 지금도 그런 것 아닙니까? 그렇습니다. 그러니까 내가 당부드리는데 내년에 또 국정감사 와서 얘기하지 않도록 부산지검의 명예와 전체 검찰의 명예를 걸고 이 사건을 공개하세요.', 'context_summary_summary_q': ' 부산지검의 명예 회복과 부산지역 사건에 대한 수사에 대한 우려가 있으며, 수사진의 교체와 관련하여 설명이 필요한데, 왜 수사진을 교체했고 새로운 수사진의 열의와 능력에 대한 보장은 어떻게 이루어지고 있나요?', 'context_summary_summary_a': '수사진 교체는 정기인사에 따라 이루어진 것이며, 이는 부산지역 사건의 수사에 영향을 미치지 않는다는 점을 강조하며, 후임 수사진과 검사들은 열의와 능력을 유지하여 전임자들과 동등한 수사 업무를 진행하기 위해 노력하고 있습니다. 부산지검은 명예 회복과 정의를 위해 노력하며 국정감사와 감사원의 감사를 수용하고 협조하고 있습니다.', 'questioner_name': '조순형', 'questioner_affiliation': '', 'questioner_position': '위원', 'question_comment': '그러니까 내가 아까 얘기한 부산지검의 명예를 회복하기 위해서 해야 된다는 얘기이고 그 이전의 지검 검사장도 이 지역사회에서 유착되었다는 설도 여기에서는 널리 유포되어 있었습니다. 그런데다가 최근에 두 지검 검사장이 이 사건의 변호인으로 선임되고 하니까 점점 부산지검은 다대ㆍ만덕사건에 관한 한 처음부터 수사를 못 하게 되어 있는 사건이다, 내가 아까 말한 대로 국정감사 때마다 요구하고 추궁하고 또 감사원 감사가 착수되고 하니까 할 수 없이 등 떠밀려서 마지못해서 하는 것 아니냐 하는 것입니다.  수사진은 왜 교체했습니까?', 'question_keyword': '부산지검, 검사장, 지역사회, 유착, 다대ㆍ만덕사건, 국정감사, 감사원 감사', 'answerer_name': '송광수', 'answerer_affiliation': '부산지방검찰청', 'answerer_position': '검사장', 'answer_comment': '인사가 된 것이 금년 2월인데 그때는 이영복이가 이미 도주했고 나머지 사람들에 대해서는 1월 중에 다 기소된 뒤였습니다. 그렇기 때문에 정기인사에 따라서 부장검사가 서울로 갈 차례이고 또 수사검사는 부부장으로 승진을 하게 되어 있었습니다.  저희들 관행에 따르면 부부장검사로 승진을 하면 다른 청에 가게 되어 있습니다. 그렇게 해서 가기는 했습니다마는 후임 부장이나 후임 검사들의 수사열의는 또 수사에 대한 파악도는 전임자들에 결코 못지않다는 것을 말씀드립니다.', 'answer_keyword': '승진, 인사, 이영복, 도주, 수사검사'}
# --------------------------------------------------
